# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %%
# Explore the dataset
batch_id = 2
sample_id = 111
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 111:
# Image - Min Value: 21 Max Value: 235
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(raw_image):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return np.array(raw_image, dtype=float) / 255.0


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(labels):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # find the number of classes
    num_classes = np.max(labels) + 1

    return np.eye(num_classes)[labels]
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    print(image_shape)
    return tf.placeholder(tf.float32, shape=(None, image_shape[0], image_shape[1], image_shape[2]), name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, shape=(None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# (32, 32, 3)
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    print(x_tensor)
    shape = x_tensor.get_shape().as_list()
    print(shape)
    print(shape[3])
    num_channels = shape[3]
    print(conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    
    #weights = tf.Variable(tf.random_normal([2, 2, 5, 10]))
    weights = tf.Variable(tf.random_normal([conv_ksize[0], conv_ksize[1], num_channels, conv_num_outputs]))
    
    biases = tf.Variable(tf.constant(1.0, shape=[conv_num_outputs]), name='Bias1')

    #conv = tf.nn.conv2d(x_tensor, weights, [1, 4, 4, 1], 'SAME', name='Conv2d_1')
    conv = tf.nn.conv2d(x_tensor, weights, [1, conv_strides[0], conv_strides[1], 1], 'SAME', name='Conv2d_1')
    
    hidden = tf.nn.relu(conv + biases)
    
    sub = tf.nn.max_pool(hidden, [1, pool_ksize[0], pool_ksize[1], 1], [1, pool_strides[0], pool_strides[1], 1], 'SAME', name='max_pool_1')
    
    return sub 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tensor("Placeholder:0", shape=(?, 32, 32, 5), dtype=float32)
# [None, 32, 32, 5]
# 5
# 10 (2, 2) (4, 4) (2, 2) (2, 2)
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    print(tf.contrib.layers.flatten(x_tensor))
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tensor("Flatten/Reshape:0", shape=(?, 1800), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs, use_relu=False):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    print(x_tensor)
    print(num_outputs)
    shape = x_tensor.get_shape().as_list()
    print(shape[1])

    weights =  tf.Variable(tf.truncated_normal([shape[1], num_outputs], stddev=0.05))
    biases = tf.Variable(tf.constant(0.05, shape=[num_outputs]))

    layer = tf.matmul(x_tensor, weights) + biases
    
    if use_relu:
        layer = tf.nn.relu(layer)
        
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tensor("Placeholder_2:0", shape=(?, 128), dtype=float32)
# 40
# 128
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    print(x_tensor)
    print(num_outputs)
    shape = x_tensor.get_shape().as_list()
    print(shape[1])
    weights = tf.Variable(tf.random_normal([shape[1], num_outputs]))
    bias = tf.Variable(tf.constant(1.0, shape=[num_outputs]))
    print(tf.matmul(x_tensor, weights) + bias)
    return tf.matmul(x_tensor, weights) + bias


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tensor("Placeholder_3:0", shape=(?, 128), dtype=float32)
# 40
# 128
# Tensor("add_9:0", shape=(?, 40), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x_tensor, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    
    print (x_tensor)
    print(keep_prob)
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    #10 (2, 2) (4, 4) (2, 2) (2, 2)
    #conv = conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv = conv2d_maxpool(x_tensor, 40, (2, 2), (4, 4), (2, 2), (2, 2))
    #conv = conv2d_maxpool(x_tensor, 40, (3, 3), (1, 1), (3, 3), (2, 2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat = flatten(conv)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully = fully_conn(flat, 10, use_relu=False)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(fully, 10)
    
    return tf.nn.dropout(out, keep_prob)
    #return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# (32, 32, 3)
# Tensor("x:0", shape=(?, 32, 32, 3), dtype=float32)
# Tensor("keep_prob:0", dtype=float32)
# Tensor("x:0", shape=(?, 32, 32, 3), dtype=float32)
# [None, 32, 32, 3]
# 3
# 40 (2, 2) (4, 4) (2, 2) (2, 2)
# Tensor("Flatten/Reshape:0", shape=(?, 640), dtype=float32)
# Tensor("Flatten_1/Reshape:0", shape=(?, 640), dtype=float32)
# 10
# 640
# Tensor("add_1:0", shape=(?, 10), dtype=float32)
# 10
# 10
# Tensor("add_2:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 32, 32, 3), dtype=float32)
# Tensor("Placeholder_1:0", dtype=float32)
# Tensor("Placeholder:0", shape=(?, 32, 32, 3), dtype=float32)
# [None, 32, 32, 3]
# 3
# 40 (2, 2) (4, 4) (2, 2) (2, 2)
# Tensor("Flatten_2/Reshape:0", shape=(?, 640), dtype=float32)
# Tensor("Flatten_3/Reshape:0", shape=(?, 640), dtype=float32)
# 10
# 640
# Tensor("add_5:0", shape=(?, 10), dtype=float32)
# 10
# 10
# Tensor("add_6:0", shape=(?, 10), dtype=float32)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    feed_dict = {
        keep_prob: keep_probability, 
        x: feature_batch,
        y: label_batch
    }
    session.run( [ optimizer], feed_dict)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """

    feed_dict = {
        keep_prob: 1, 
        x: valid_features,
        y: valid_labels
    }
    c, a = session.run(
        [ cost, accuracy],
        feed_dict)

    print("loss {:g}, acc {:g}".format(c, a))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 120
batch_size = 256
keep_probability = 0.9

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    #sess.run(tf.global_variables_initializer())
    tf.initialize_all_variables().run()
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss 2.60283, acc 0.166
# Epoch  2, CIFAR-10 Batch 1:  loss 2.25555, acc 0.2146
# Epoch  3, CIFAR-10 Batch 1:  loss 2.1153, acc 0.2516
# Epoch  4, CIFAR-10 Batch 1:  loss 2.01936, acc 0.283
# Epoch  5, CIFAR-10 Batch 1:  loss 1.97093, acc 0.2956
# Epoch  6, CIFAR-10 Batch 1:  loss 1.94992, acc 0.3086
# Epoch  7, CIFAR-10 Batch 1:  loss 1.94404, acc 0.3136
# Epoch  8, CIFAR-10 Batch 1:  loss 1.90342, acc 0.3254
# Epoch  9, CIFAR-10 Batch 1:  loss 1.85991, acc 0.3468
# Epoch 10, CIFAR-10 Batch 1:  loss 1.83396, acc 0.3476
# Epoch 11, CIFAR-10 Batch 1:  loss 1.82356, acc 0.357
# Epoch 12, CIFAR-10 Batch 1:  loss 1.81306, acc 0.3452
# Epoch 13, CIFAR-10 Batch 1:  loss 1.79139, acc 0.357
# Epoch 14, CIFAR-10 Batch 1:  loss 1.77956, acc 0.3666
# Epoch 15, CIFAR-10 Batch 1:  loss 1.78708, acc 0.3618
# Epoch 16, CIFAR-10 Batch 1:  loss 1.75692, acc 0.3758
# Epoch 17, CIFAR-10 Batch 1:  loss 1.76936, acc 0.3656
# Epoch 18, CIFAR-10 Batch 1:  loss 1.75305, acc 0.3834
# Epoch 19, CIFAR-10 Batch 1:  loss 1.73472, acc 0.3776
# Epoch 20, CIFAR-10 Batch 1:  loss 1.73564, acc 0.3784
# Epoch 21, CIFAR-10 Batch 1:  loss 1.72277, acc 0.3876
# Epoch 22, CIFAR-10 Batch 1:  loss 1.71873, acc 0.3922
# Epoch 23, CIFAR-10 Batch 1:  loss 1.72396, acc 0.3908
# Epoch 24, CIFAR-10 Batch 1:  loss 1.70782, acc 0.3974
# Epoch 25, CIFAR-10 Batch 1:  loss 1.68553, acc 0.4024
# Epoch 26, CIFAR-10 Batch 1:  loss 1.68752, acc 0.4028
# Epoch 27, CIFAR-10 Batch 1:  loss 1.72226, acc 0.3872
# Epoch 28, CIFAR-10 Batch 1:  loss 1.6931, acc 0.3984
# Epoch 29, CIFAR-10 Batch 1:  loss 1.68764, acc 0.4028
# Epoch 30, CIFAR-10 Batch 1:  loss 1.66472, acc 0.4052
# Epoch 31, CIFAR-10 Batch 1:  loss 1.67583, acc 0.404
# Epoch 32, CIFAR-10 Batch 1:  loss 1.66989, acc 0.4084
# Epoch 33, CIFAR-10 Batch 1:  loss 1.69605, acc 0.3992
# Epoch 34, CIFAR-10 Batch 1:  loss 1.65043, acc 0.4096
# Epoch 35, CIFAR-10 Batch 1:  loss 1.66062, acc 0.4092
# Epoch 36, CIFAR-10 Batch 1:  loss 1.63908, acc 0.418
# Epoch 37, CIFAR-10 Batch 1:  loss 1.65806, acc 0.4112
# Epoch 38, CIFAR-10 Batch 1:  loss 1.63898, acc 0.4164
# Epoch 39, CIFAR-10 Batch 1:  loss 1.65772, acc 0.4126
# Epoch 40, CIFAR-10 Batch 1:  loss 1.63501, acc 0.4222
# Epoch 41, CIFAR-10 Batch 1:  loss 1.65056, acc 0.4126
# Epoch 42, CIFAR-10 Batch 1:  loss 1.6425, acc 0.419
# Epoch 43, CIFAR-10 Batch 1:  loss 1.64507, acc 0.4168
# Epoch 44, CIFAR-10 Batch 1:  loss 1.63289, acc 0.4182
# Epoch 45, CIFAR-10 Batch 1:  loss 1.62923, acc 0.425
# Epoch 46, CIFAR-10 Batch 1:  loss 1.63849, acc 0.4236
# Epoch 47, CIFAR-10 Batch 1:  loss 1.62982, acc 0.4264
# Epoch 48, CIFAR-10 Batch 1:  loss 1.63181, acc 0.4236
# Epoch 49, CIFAR-10 Batch 1:  loss 1.61219, acc 0.4326
# Epoch 50, CIFAR-10 Batch 1:  loss 1.63455, acc 0.4196
# Epoch 51, CIFAR-10 Batch 1:  loss 1.60061, acc 0.4366
# Epoch 52, CIFAR-10 Batch 1:  loss 1.61692, acc 0.4268
# Epoch 53, CIFAR-10 Batch 1:  loss 1.61101, acc 0.4342
# Epoch 54, CIFAR-10 Batch 1:  loss 1.6039, acc 0.4328
# Epoch 55, CIFAR-10 Batch 1:  loss 1.59386, acc 0.4384
# Epoch 56, CIFAR-10 Batch 1:  loss 1.58399, acc 0.439
# Epoch 57, CIFAR-10 Batch 1:  loss 1.59301, acc 0.4382
# Epoch 58, CIFAR-10 Batch 1:  loss 1.60172, acc 0.4338
# Epoch 59, CIFAR-10 Batch 1:  loss 1.60196, acc 0.4352
# Epoch 60, CIFAR-10 Batch 1:  loss 1.58187, acc 0.4448
# Epoch 61, CIFAR-10 Batch 1:  loss 1.57706, acc 0.447
# Epoch 62, CIFAR-10 Batch 1:  loss 1.59765, acc 0.4388
# Epoch 63, CIFAR-10 Batch 1:  loss 1.57091, acc 0.4486
# Epoch 64, CIFAR-10 Batch 1:  loss 1.58674, acc 0.4452
# Epoch 65, CIFAR-10 Batch 1:  loss 1.56687, acc 0.447
# Epoch 66, CIFAR-10 Batch 1:  loss 1.56452, acc 0.4524
# Epoch 67, CIFAR-10 Batch 1:  loss 1.5937, acc 0.438
# Epoch 68, CIFAR-10 Batch 1:  loss 1.57934, acc 0.4412
# Epoch 69, CIFAR-10 Batch 1:  loss 1.56051, acc 0.4488
# Epoch 70, CIFAR-10 Batch 1:  loss 1.57499, acc 0.4434
# Epoch 71, CIFAR-10 Batch 1:  loss 1.5689, acc 0.4464
# Epoch 72, CIFAR-10 Batch 1:  loss 1.6029, acc 0.4276
# Epoch 73, CIFAR-10 Batch 1:  loss 1.57536, acc 0.4458
# Epoch 74, CIFAR-10 Batch 1:  loss 1.58998, acc 0.4408
# Epoch 75, CIFAR-10 Batch 1:  loss 1.55267, acc 0.4518
# Epoch 76, CIFAR-10 Batch 1:  loss 1.56864, acc 0.4496
# Epoch 77, CIFAR-10 Batch 1:  loss 1.55395, acc 0.4498
# Epoch 78, CIFAR-10 Batch 1:  loss 1.5764, acc 0.4474
# Epoch 79, CIFAR-10 Batch 1:  loss 1.55723, acc 0.4504
# Epoch 80, CIFAR-10 Batch 1:  loss 1.54173, acc 0.4574
# Epoch 81, CIFAR-10 Batch 1:  loss 1.54831, acc 0.459
# Epoch 82, CIFAR-10 Batch 1:  loss 1.55286, acc 0.4532
# Epoch 83, CIFAR-10 Batch 1:  loss 1.53896, acc 0.4566
# Epoch 84, CIFAR-10 Batch 1:  loss 1.54363, acc 0.4596
# Epoch 85, CIFAR-10 Batch 1:  loss 1.5502, acc 0.4544
# Epoch 86, CIFAR-10 Batch 1:  loss 1.57136, acc 0.443
# Epoch 87, CIFAR-10 Batch 1:  loss 1.55174, acc 0.4556
# Epoch 88, CIFAR-10 Batch 1:  loss 1.54565, acc 0.46
# Epoch 89, CIFAR-10 Batch 1:  loss 1.55332, acc 0.4492
# Epoch 90, CIFAR-10 Batch 1:  loss 1.55199, acc 0.4526
# Epoch 91, CIFAR-10 Batch 1:  loss 1.55644, acc 0.4496
# Epoch 92, CIFAR-10 Batch 1:  loss 1.54244, acc 0.4588
# Epoch 93, CIFAR-10 Batch 1:  loss 1.55946, acc 0.4466
# Epoch 94, CIFAR-10 Batch 1:  loss 1.52312, acc 0.4642
# Epoch 95, CIFAR-10 Batch 1:  loss 1.53663, acc 0.461
# Epoch 96, CIFAR-10 Batch 1:  loss 1.52516, acc 0.467
# Epoch 97, CIFAR-10 Batch 1:  loss 1.54565, acc 0.456
# Epoch 98, CIFAR-10 Batch 1:  loss 1.54576, acc 0.452
# Epoch 99, CIFAR-10 Batch 1:  loss 1.53786, acc 0.4558
# Epoch 100, CIFAR-10 Batch 1:  loss 1.53088, acc 0.4608
# Epoch 101, CIFAR-10 Batch 1:  loss 1.53889, acc 0.4548
# Epoch 102, CIFAR-10 Batch 1:  loss 1.52692, acc 0.464
# Epoch 103, CIFAR-10 Batch 1:  loss 1.53768, acc 0.4558
# Epoch 104, CIFAR-10 Batch 1:  loss 1.54059, acc 0.4542
# Epoch 105, CIFAR-10 Batch 1:  loss 1.55018, acc 0.4536
# Epoch 106, CIFAR-10 Batch 1:  loss 1.54054, acc 0.4532
# Epoch 107, CIFAR-10 Batch 1:  loss 1.5243, acc 0.4662
# Epoch 108, CIFAR-10 Batch 1:  loss 1.53558, acc 0.4554
# Epoch 109, CIFAR-10 Batch 1:  loss 1.52596, acc 0.4642
# Epoch 110, CIFAR-10 Batch 1:  loss 1.54416, acc 0.4592
# Epoch 111, CIFAR-10 Batch 1:  loss 1.52195, acc 0.4688
# Epoch 112, CIFAR-10 Batch 1:  loss 1.54633, acc 0.4506
# Epoch 113, CIFAR-10 Batch 1:  loss 1.5305, acc 0.4656
# Epoch 114, CIFAR-10 Batch 1:  loss 1.52386, acc 0.4636
# Epoch 115, CIFAR-10 Batch 1:  loss 1.53444, acc 0.4544
# Epoch 116, CIFAR-10 Batch 1:  loss 1.52917, acc 0.4658
# Epoch 117, CIFAR-10 Batch 1:  loss 1.52564, acc 0.467
# Epoch 118, CIFAR-10 Batch 1:  loss 1.52779, acc 0.4608
# Epoch 119, CIFAR-10 Batch 1:  loss 1.52809, acc 0.4634
# Epoch 120, CIFAR-10 Batch 1:  loss 1.52607, acc 0.4662

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    #sess.run(tf.global_variables_initializer())
    tf.initialize_all_variables().run()
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss 2.86552, acc 0.1368
# Epoch  1, CIFAR-10 Batch 2:  loss 2.39711, acc 0.1862
# Epoch  1, CIFAR-10 Batch 3:  loss 2.23648, acc 0.2232
# Epoch  1, CIFAR-10 Batch 4:  loss 2.13905, acc 0.2434
# Epoch  1, CIFAR-10 Batch 5:  loss 2.14559, acc 0.254
# Epoch  2, CIFAR-10 Batch 1:  loss 1.98851, acc 0.2916
# Epoch  2, CIFAR-10 Batch 2:  loss 1.94178, acc 0.3158
# Epoch  2, CIFAR-10 Batch 3:  loss 1.9891, acc 0.2996
# Epoch  2, CIFAR-10 Batch 4:  loss 1.87498, acc 0.3212
# Epoch  2, CIFAR-10 Batch 5:  loss 1.85295, acc 0.3384
# Epoch  3, CIFAR-10 Batch 1:  loss 1.86663, acc 0.3282
# Epoch  3, CIFAR-10 Batch 2:  loss 1.85221, acc 0.3364
# Epoch  3, CIFAR-10 Batch 3:  loss 1.81953, acc 0.3502
# Epoch  3, CIFAR-10 Batch 4:  loss 1.78192, acc 0.358
# Epoch  3, CIFAR-10 Batch 5:  loss 1.75548, acc 0.3732
# Epoch  4, CIFAR-10 Batch 1:  loss 1.9076, acc 0.325
# Epoch  4, CIFAR-10 Batch 2:  loss 1.80847, acc 0.3548
# Epoch  4, CIFAR-10 Batch 3:  loss 1.79077, acc 0.3556
# Epoch  4, CIFAR-10 Batch 4:  loss 1.71817, acc 0.386
# Epoch  4, CIFAR-10 Batch 5:  loss 1.70401, acc 0.3976
# Epoch  5, CIFAR-10 Batch 1:  loss 1.74077, acc 0.375
# Epoch  5, CIFAR-10 Batch 2:  loss 1.80823, acc 0.3572
# Epoch  5, CIFAR-10 Batch 3:  loss 1.78149, acc 0.3698
# Epoch  5, CIFAR-10 Batch 4:  loss 1.69702, acc 0.3944
# Epoch  5, CIFAR-10 Batch 5:  loss 1.67269, acc 0.4078
# Epoch  6, CIFAR-10 Batch 1:  loss 1.74295, acc 0.3772
# Epoch  6, CIFAR-10 Batch 2:  loss 1.71499, acc 0.3906
# Epoch  6, CIFAR-10 Batch 3:  loss 1.71996, acc 0.3932
# Epoch  6, CIFAR-10 Batch 4:  loss 1.69161, acc 0.3988
# Epoch  6, CIFAR-10 Batch 5:  loss 1.64762, acc 0.419
# Epoch  7, CIFAR-10 Batch 1:  loss 1.72052, acc 0.3822
# Epoch  7, CIFAR-10 Batch 2:  loss 1.7004, acc 0.4014
# Epoch  7, CIFAR-10 Batch 3:  loss 1.66243, acc 0.414
# Epoch  7, CIFAR-10 Batch 4:  loss 1.62603, acc 0.4224
# Epoch  7, CIFAR-10 Batch 5:  loss 1.62286, acc 0.4224
# Epoch  8, CIFAR-10 Batch 1:  loss 1.67452, acc 0.3962
# Epoch  8, CIFAR-10 Batch 2:  loss 1.68137, acc 0.4066
# Epoch  8, CIFAR-10 Batch 3:  loss 1.66064, acc 0.417
# Epoch  8, CIFAR-10 Batch 4:  loss 1.61122, acc 0.4288
# Epoch  8, CIFAR-10 Batch 5:  loss 1.59027, acc 0.4386
# Epoch  9, CIFAR-10 Batch 1:  loss 1.64481, acc 0.4172
# Epoch  9, CIFAR-10 Batch 2:  loss 1.63626, acc 0.4268
# Epoch  9, CIFAR-10 Batch 3:  loss 1.6438, acc 0.4216
# Epoch  9, CIFAR-10 Batch 4:  loss 1.59265, acc 0.435
# Epoch  9, CIFAR-10 Batch 5:  loss 1.58372, acc 0.4412
# Epoch 10, CIFAR-10 Batch 1:  loss 1.61664, acc 0.424
# Epoch 10, CIFAR-10 Batch 2:  loss 1.62593, acc 0.421
# Epoch 10, CIFAR-10 Batch 3:  loss 1.6404, acc 0.4252
# Epoch 10, CIFAR-10 Batch 4:  loss 1.56448, acc 0.4512
# Epoch 10, CIFAR-10 Batch 5:  loss 1.5739, acc 0.4478
# Epoch 11, CIFAR-10 Batch 1:  loss 1.58665, acc 0.436
# Epoch 11, CIFAR-10 Batch 2:  loss 1.62267, acc 0.4244
# Epoch 11, CIFAR-10 Batch 3:  loss 1.58436, acc 0.4416
# Epoch 11, CIFAR-10 Batch 4:  loss 1.55465, acc 0.453
# Epoch 11, CIFAR-10 Batch 5:  loss 1.56668, acc 0.4486
# Epoch 12, CIFAR-10 Batch 1:  loss 1.58125, acc 0.4352
# Epoch 12, CIFAR-10 Batch 2:  loss 1.58605, acc 0.4374
# Epoch 12, CIFAR-10 Batch 3:  loss 1.58229, acc 0.4378
# Epoch 12, CIFAR-10 Batch 4:  loss 1.55763, acc 0.4544
# Epoch 12, CIFAR-10 Batch 5:  loss 1.54403, acc 0.4564
# Epoch 13, CIFAR-10 Batch 1:  loss 1.57477, acc 0.4316
# Epoch 13, CIFAR-10 Batch 2:  loss 1.58484, acc 0.4378
# Epoch 13, CIFAR-10 Batch 3:  loss 1.56176, acc 0.451
# Epoch 13, CIFAR-10 Batch 4:  loss 1.54626, acc 0.4554
# Epoch 13, CIFAR-10 Batch 5:  loss 1.55167, acc 0.4542
# Epoch 14, CIFAR-10 Batch 1:  loss 1.54541, acc 0.4476
# Epoch 14, CIFAR-10 Batch 2:  loss 1.52817, acc 0.4588
# Epoch 14, CIFAR-10 Batch 3:  loss 1.55169, acc 0.4538
# Epoch 14, CIFAR-10 Batch 4:  loss 1.54368, acc 0.4574
# Epoch 14, CIFAR-10 Batch 5:  loss 1.56104, acc 0.4484
# Epoch 15, CIFAR-10 Batch 1:  loss 1.53963, acc 0.4492
# Epoch 15, CIFAR-10 Batch 2:  loss 1.54351, acc 0.4522
# Epoch 15, CIFAR-10 Batch 3:  loss 1.53594, acc 0.465
# Epoch 15, CIFAR-10 Batch 4:  loss 1.53578, acc 0.4604
# Epoch 15, CIFAR-10 Batch 5:  loss 1.51786, acc 0.4694
# Epoch 16, CIFAR-10 Batch 1:  loss 1.54818, acc 0.4474
# Epoch 16, CIFAR-10 Batch 2:  loss 1.54937, acc 0.4462
# Epoch 16, CIFAR-10 Batch 3:  loss 1.5496, acc 0.454
# Epoch 16, CIFAR-10 Batch 4:  loss 1.52796, acc 0.4644
# Epoch 16, CIFAR-10 Batch 5:  loss 1.52319, acc 0.4642
# Epoch 17, CIFAR-10 Batch 1:  loss 1.51582, acc 0.459
# Epoch 17, CIFAR-10 Batch 2:  loss 1.51886, acc 0.4634
# Epoch 17, CIFAR-10 Batch 3:  loss 1.53882, acc 0.4606
# Epoch 17, CIFAR-10 Batch 4:  loss 1.50966, acc 0.4714
# Epoch 17, CIFAR-10 Batch 5:  loss 1.49482, acc 0.4774
# Epoch 18, CIFAR-10 Batch 1:  loss 1.49772, acc 0.4678
# Epoch 18, CIFAR-10 Batch 2:  loss 1.51576, acc 0.4634
# Epoch 18, CIFAR-10 Batch 3:  loss 1.53642, acc 0.4594
# Epoch 18, CIFAR-10 Batch 4:  loss 1.54584, acc 0.4598
# Epoch 18, CIFAR-10 Batch 5:  loss 1.50333, acc 0.4642
# Epoch 19, CIFAR-10 Batch 1:  loss 1.5263, acc 0.458
# Epoch 19, CIFAR-10 Batch 2:  loss 1.50006, acc 0.471
# Epoch 19, CIFAR-10 Batch 3:  loss 1.51679, acc 0.4664
# Epoch 19, CIFAR-10 Batch 4:  loss 1.50487, acc 0.47
# Epoch 19, CIFAR-10 Batch 5:  loss 1.48208, acc 0.4824
# Epoch 20, CIFAR-10 Batch 1:  loss 1.50519, acc 0.4644
# Epoch 20, CIFAR-10 Batch 2:  loss 1.49922, acc 0.4748
# Epoch 20, CIFAR-10 Batch 3:  loss 1.4936, acc 0.4772
# Epoch 20, CIFAR-10 Batch 4:  loss 1.4938, acc 0.4742
# Epoch 20, CIFAR-10 Batch 5:  loss 1.50932, acc 0.4674
# Epoch 21, CIFAR-10 Batch 1:  loss 1.50233, acc 0.4652
# Epoch 21, CIFAR-10 Batch 2:  loss 1.50105, acc 0.4702
# Epoch 21, CIFAR-10 Batch 3:  loss 1.48841, acc 0.4794
# Epoch 21, CIFAR-10 Batch 4:  loss 1.49189, acc 0.4762
# Epoch 21, CIFAR-10 Batch 5:  loss 1.47242, acc 0.4892
# Epoch 22, CIFAR-10 Batch 1:  loss 1.50519, acc 0.4638
# Epoch 22, CIFAR-10 Batch 2:  loss 1.48683, acc 0.4746
# Epoch 22, CIFAR-10 Batch 3:  loss 1.51425, acc 0.4632
# Epoch 22, CIFAR-10 Batch 4:  loss 1.4844, acc 0.483
# Epoch 22, CIFAR-10 Batch 5:  loss 1.49918, acc 0.4726
# Epoch 23, CIFAR-10 Batch 1:  loss 1.50066, acc 0.4654
# Epoch 23, CIFAR-10 Batch 2:  loss 1.47884, acc 0.483
# Epoch 23, CIFAR-10 Batch 3:  loss 1.48765, acc 0.4784
# Epoch 23, CIFAR-10 Batch 4:  loss 1.50201, acc 0.4702
# Epoch 23, CIFAR-10 Batch 5:  loss 1.48981, acc 0.4768
# Epoch 24, CIFAR-10 Batch 1:  loss 1.50583, acc 0.4638
# Epoch 24, CIFAR-10 Batch 2:  loss 1.48169, acc 0.4794
# Epoch 24, CIFAR-10 Batch 3:  loss 1.47376, acc 0.4814
# Epoch 24, CIFAR-10 Batch 4:  loss 1.49674, acc 0.471
# Epoch 24, CIFAR-10 Batch 5:  loss 1.48833, acc 0.4764
# Epoch 25, CIFAR-10 Batch 1:  loss 1.4702, acc 0.481
# Epoch 25, CIFAR-10 Batch 2:  loss 1.48037, acc 0.4808
# Epoch 25, CIFAR-10 Batch 3:  loss 1.47979, acc 0.4786
# Epoch 25, CIFAR-10 Batch 4:  loss 1.48763, acc 0.475
# Epoch 25, CIFAR-10 Batch 5:  loss 1.49739, acc 0.4702
# Epoch 26, CIFAR-10 Batch 1:  loss 1.47668, acc 0.477
# Epoch 26, CIFAR-10 Batch 2:  loss 1.46201, acc 0.4822
# Epoch 26, CIFAR-10 Batch 3:  loss 1.4767, acc 0.473
# Epoch 26, CIFAR-10 Batch 4:  loss 1.49284, acc 0.471
# Epoch 26, CIFAR-10 Batch 5:  loss 1.50216, acc 0.4728
# Epoch 27, CIFAR-10 Batch 1:  loss 1.46737, acc 0.4806
# Epoch 27, CIFAR-10 Batch 2:  loss 1.47141, acc 0.4786
# Epoch 27, CIFAR-10 Batch 3:  loss 1.48511, acc 0.468
# Epoch 27, CIFAR-10 Batch 4:  loss 1.48205, acc 0.4762
# Epoch 27, CIFAR-10 Batch 5:  loss 1.47625, acc 0.48
# Epoch 28, CIFAR-10 Batch 1:  loss 1.48145, acc 0.4742
# Epoch 28, CIFAR-10 Batch 2:  loss 1.45785, acc 0.4872
# Epoch 28, CIFAR-10 Batch 3:  loss 1.48769, acc 0.47
# Epoch 28, CIFAR-10 Batch 4:  loss 1.54467, acc 0.4548
# Epoch 28, CIFAR-10 Batch 5:  loss 1.47949, acc 0.4818
# Epoch 29, CIFAR-10 Batch 1:  loss 1.46997, acc 0.4762
# Epoch 29, CIFAR-10 Batch 2:  loss 1.45785, acc 0.4854
# Epoch 29, CIFAR-10 Batch 3:  loss 1.48018, acc 0.474
# Epoch 29, CIFAR-10 Batch 4:  loss 1.48852, acc 0.4738
# Epoch 29, CIFAR-10 Batch 5:  loss 1.47407, acc 0.4802
# Epoch 30, CIFAR-10 Batch 1:  loss 1.47067, acc 0.4758
# Epoch 30, CIFAR-10 Batch 2:  loss 1.44389, acc 0.4904
# Epoch 30, CIFAR-10 Batch 3:  loss 1.44685, acc 0.4898
# Epoch 30, CIFAR-10 Batch 4:  loss 1.47512, acc 0.4794
# Epoch 30, CIFAR-10 Batch 5:  loss 1.45744, acc 0.4842
# Epoch 31, CIFAR-10 Batch 1:  loss 1.45578, acc 0.4836
# Epoch 31, CIFAR-10 Batch 2:  loss 1.44273, acc 0.4884
# Epoch 31, CIFAR-10 Batch 3:  loss 1.44806, acc 0.489
# Epoch 31, CIFAR-10 Batch 4:  loss 1.5268, acc 0.4606
# Epoch 31, CIFAR-10 Batch 5:  loss 1.51349, acc 0.4648
# Epoch 32, CIFAR-10 Batch 1:  loss 1.45279, acc 0.485
# Epoch 32, CIFAR-10 Batch 2:  loss 1.44481, acc 0.489
# Epoch 32, CIFAR-10 Batch 3:  loss 1.44689, acc 0.4928
# Epoch 32, CIFAR-10 Batch 4:  loss 1.46545, acc 0.4836
# Epoch 32, CIFAR-10 Batch 5:  loss 1.51489, acc 0.4652
# Epoch 33, CIFAR-10 Batch 1:  loss 1.46529, acc 0.4812
# Epoch 33, CIFAR-10 Batch 2:  loss 1.44379, acc 0.4918
# Epoch 33, CIFAR-10 Batch 3:  loss 1.43934, acc 0.4944
# Epoch 33, CIFAR-10 Batch 4:  loss 1.48008, acc 0.4768
# Epoch 33, CIFAR-10 Batch 5:  loss 1.46563, acc 0.4832
# Epoch 34, CIFAR-10 Batch 1:  loss 1.44688, acc 0.4858
# Epoch 34, CIFAR-10 Batch 2:  loss 1.43927, acc 0.4896
# Epoch 34, CIFAR-10 Batch 3:  loss 1.43349, acc 0.4964
# Epoch 34, CIFAR-10 Batch 4:  loss 1.4662, acc 0.4834
# Epoch 34, CIFAR-10 Batch 5:  loss 1.47412, acc 0.477
# Epoch 35, CIFAR-10 Batch 1:  loss 1.4365, acc 0.4918
# Epoch 35, CIFAR-10 Batch 2:  loss 1.43729, acc 0.4928
# Epoch 35, CIFAR-10 Batch 3:  loss 1.43489, acc 0.4976
# Epoch 35, CIFAR-10 Batch 4:  loss 1.43856, acc 0.4972
# Epoch 35, CIFAR-10 Batch 5:  loss 1.44936, acc 0.4882
# Epoch 36, CIFAR-10 Batch 1:  loss 1.43347, acc 0.4942
# Epoch 36, CIFAR-10 Batch 2:  loss 1.43846, acc 0.488
# Epoch 36, CIFAR-10 Batch 3:  loss 1.45168, acc 0.4872
# Epoch 36, CIFAR-10 Batch 4:  loss 1.46559, acc 0.4796
# Epoch 36, CIFAR-10 Batch 5:  loss 1.45392, acc 0.4834
# Epoch 37, CIFAR-10 Batch 1:  loss 1.43727, acc 0.4942
# Epoch 37, CIFAR-10 Batch 2:  loss 1.43949, acc 0.4936
# Epoch 37, CIFAR-10 Batch 3:  loss 1.43877, acc 0.4898
# Epoch 37, CIFAR-10 Batch 4:  loss 1.44196, acc 0.4918
# Epoch 37, CIFAR-10 Batch 5:  loss 1.43085, acc 0.4922
# Epoch 38, CIFAR-10 Batch 1:  loss 1.41813, acc 0.501
# Epoch 38, CIFAR-10 Batch 2:  loss 1.43756, acc 0.4902
# Epoch 38, CIFAR-10 Batch 3:  loss 1.43504, acc 0.497
# Epoch 38, CIFAR-10 Batch 4:  loss 1.42457, acc 0.5024
# Epoch 38, CIFAR-10 Batch 5:  loss 1.51689, acc 0.468
# Epoch 39, CIFAR-10 Batch 1:  loss 1.43494, acc 0.4954
# Epoch 39, CIFAR-10 Batch 2:  loss 1.43409, acc 0.4964
# Epoch 39, CIFAR-10 Batch 3:  loss 1.45058, acc 0.4834
# Epoch 39, CIFAR-10 Batch 4:  loss 1.43375, acc 0.4954
# Epoch 39, CIFAR-10 Batch 5:  loss 1.43357, acc 0.4918
# Epoch 40, CIFAR-10 Batch 1:  loss 1.4328, acc 0.496
# Epoch 40, CIFAR-10 Batch 2:  loss 1.43877, acc 0.4882
# Epoch 40, CIFAR-10 Batch 3:  loss 1.42888, acc 0.4956
# Epoch 40, CIFAR-10 Batch 4:  loss 1.42594, acc 0.5022
# Epoch 40, CIFAR-10 Batch 5:  loss 1.44244, acc 0.4896
# Epoch 41, CIFAR-10 Batch 1:  loss 1.44317, acc 0.4888
# Epoch 41, CIFAR-10 Batch 2:  loss 1.42234, acc 0.502
# Epoch 41, CIFAR-10 Batch 3:  loss 1.44493, acc 0.488
# Epoch 41, CIFAR-10 Batch 4:  loss 1.42935, acc 0.4988
# Epoch 41, CIFAR-10 Batch 5:  loss 1.4367, acc 0.4886
# Epoch 42, CIFAR-10 Batch 1:  loss 1.43639, acc 0.4896
# Epoch 42, CIFAR-10 Batch 2:  loss 1.44931, acc 0.4852
# Epoch 42, CIFAR-10 Batch 3:  loss 1.40875, acc 0.5034
# Epoch 42, CIFAR-10 Batch 4:  loss 1.42833, acc 0.4976
# Epoch 42, CIFAR-10 Batch 5:  loss 1.43255, acc 0.4972
# Epoch 43, CIFAR-10 Batch 1:  loss 1.41307, acc 0.5044
# Epoch 43, CIFAR-10 Batch 2:  loss 1.43553, acc 0.4904
# Epoch 43, CIFAR-10 Batch 3:  loss 1.4221, acc 0.496
# Epoch 43, CIFAR-10 Batch 4:  loss 1.42032, acc 0.5006
# Epoch 43, CIFAR-10 Batch 5:  loss 1.43098, acc 0.4912
# Epoch 44, CIFAR-10 Batch 1:  loss 1.41737, acc 0.5
# Epoch 44, CIFAR-10 Batch 2:  loss 1.42995, acc 0.492
# Epoch 44, CIFAR-10 Batch 3:  loss 1.43145, acc 0.4938
# Epoch 44, CIFAR-10 Batch 4:  loss 1.41594, acc 0.5026
# Epoch 44, CIFAR-10 Batch 5:  loss 1.44154, acc 0.486
# Epoch 45, CIFAR-10 Batch 1:  loss 1.40854, acc 0.5044
# Epoch 45, CIFAR-10 Batch 2:  loss 1.4305, acc 0.4956
# Epoch 45, CIFAR-10 Batch 3:  loss 1.42428, acc 0.4974
# Epoch 45, CIFAR-10 Batch 4:  loss 1.42199, acc 0.4998
# Epoch 45, CIFAR-10 Batch 5:  loss 1.43676, acc 0.4926
# Epoch 46, CIFAR-10 Batch 1:  loss 1.4155, acc 0.5022
# Epoch 46, CIFAR-10 Batch 2:  loss 1.44895, acc 0.4852
# Epoch 46, CIFAR-10 Batch 3:  loss 1.40658, acc 0.5002
# Epoch 46, CIFAR-10 Batch 4:  loss 1.42483, acc 0.4988
# Epoch 46, CIFAR-10 Batch 5:  loss 1.44004, acc 0.4908
# Epoch 47, CIFAR-10 Batch 1:  loss 1.43036, acc 0.4964
# Epoch 47, CIFAR-10 Batch 2:  loss 1.42792, acc 0.4938
# Epoch 47, CIFAR-10 Batch 3:  loss 1.40251, acc 0.5064
# Epoch 47, CIFAR-10 Batch 4:  loss 1.42422, acc 0.5
# Epoch 47, CIFAR-10 Batch 5:  loss 1.41857, acc 0.499
# Epoch 48, CIFAR-10 Batch 1:  loss 1.43965, acc 0.4984
# Epoch 48, CIFAR-10 Batch 2:  loss 1.42172, acc 0.497
# Epoch 48, CIFAR-10 Batch 3:  loss 1.39261, acc 0.5078
# Epoch 48, CIFAR-10 Batch 4:  loss 1.40778, acc 0.5034
# Epoch 48, CIFAR-10 Batch 5:  loss 1.4314, acc 0.488
# Epoch 49, CIFAR-10 Batch 1:  loss 1.4212, acc 0.502
# Epoch 49, CIFAR-10 Batch 2:  loss 1.42697, acc 0.4922
# Epoch 49, CIFAR-10 Batch 3:  loss 1.41382, acc 0.4988
# Epoch 49, CIFAR-10 Batch 4:  loss 1.41746, acc 0.5022
# Epoch 49, CIFAR-10 Batch 5:  loss 1.43472, acc 0.4864
# Epoch 50, CIFAR-10 Batch 1:  loss 1.43183, acc 0.495
# Epoch 50, CIFAR-10 Batch 2:  loss 1.42349, acc 0.4942
# Epoch 50, CIFAR-10 Batch 3:  loss 1.39791, acc 0.5076
# Epoch 50, CIFAR-10 Batch 4:  loss 1.42704, acc 0.492
# Epoch 50, CIFAR-10 Batch 5:  loss 1.40944, acc 0.5
# Epoch 51, CIFAR-10 Batch 1:  loss 1.43789, acc 0.495
# Epoch 51, CIFAR-10 Batch 2:  loss 1.40434, acc 0.5004
# Epoch 51, CIFAR-10 Batch 3:  loss 1.38532, acc 0.5152
# Epoch 51, CIFAR-10 Batch 4:  loss 1.44078, acc 0.4874
# Epoch 51, CIFAR-10 Batch 5:  loss 1.42407, acc 0.4968
# Epoch 52, CIFAR-10 Batch 1:  loss 1.41253, acc 0.5038
# Epoch 52, CIFAR-10 Batch 2:  loss 1.40039, acc 0.5018
# Epoch 52, CIFAR-10 Batch 3:  loss 1.38723, acc 0.5124
# Epoch 52, CIFAR-10 Batch 4:  loss 1.41656, acc 0.4936
# Epoch 52, CIFAR-10 Batch 5:  loss 1.4154, acc 0.4964
# Epoch 53, CIFAR-10 Batch 1:  loss 1.43593, acc 0.494
# Epoch 53, CIFAR-10 Batch 2:  loss 1.41844, acc 0.498
# Epoch 53, CIFAR-10 Batch 3:  loss 1.40477, acc 0.5076
# Epoch 53, CIFAR-10 Batch 4:  loss 1.40965, acc 0.5046
# Epoch 53, CIFAR-10 Batch 5:  loss 1.41437, acc 0.4948
# Epoch 54, CIFAR-10 Batch 1:  loss 1.42815, acc 0.4954
# Epoch 54, CIFAR-10 Batch 2:  loss 1.43097, acc 0.4916
# Epoch 54, CIFAR-10 Batch 3:  loss 1.39004, acc 0.51
# Epoch 54, CIFAR-10 Batch 4:  loss 1.40676, acc 0.5036
# Epoch 54, CIFAR-10 Batch 5:  loss 1.39679, acc 0.5066
# Epoch 55, CIFAR-10 Batch 1:  loss 1.41855, acc 0.498
# Epoch 55, CIFAR-10 Batch 2:  loss 1.40875, acc 0.5014
# Epoch 55, CIFAR-10 Batch 3:  loss 1.39648, acc 0.5054
# Epoch 55, CIFAR-10 Batch 4:  loss 1.40842, acc 0.5032
# Epoch 55, CIFAR-10 Batch 5:  loss 1.39097, acc 0.5074
# Epoch 56, CIFAR-10 Batch 1:  loss 1.3913, acc 0.5088
# Epoch 56, CIFAR-10 Batch 2:  loss 1.39348, acc 0.5078
# Epoch 56, CIFAR-10 Batch 3:  loss 1.38922, acc 0.505
# Epoch 56, CIFAR-10 Batch 4:  loss 1.39238, acc 0.507
# Epoch 56, CIFAR-10 Batch 5:  loss 1.3987, acc 0.5102
# Epoch 57, CIFAR-10 Batch 1:  loss 1.40375, acc 0.5038
# Epoch 57, CIFAR-10 Batch 2:  loss 1.385, acc 0.5118
# Epoch 57, CIFAR-10 Batch 3:  loss 1.39404, acc 0.5058
# Epoch 57, CIFAR-10 Batch 4:  loss 1.40203, acc 0.5092
# Epoch 57, CIFAR-10 Batch 5:  loss 1.38219, acc 0.5158
# Epoch 58, CIFAR-10 Batch 1:  loss 1.39895, acc 0.5084
# Epoch 58, CIFAR-10 Batch 2:  loss 1.396, acc 0.504
# Epoch 58, CIFAR-10 Batch 3:  loss 1.39563, acc 0.5002
# Epoch 58, CIFAR-10 Batch 4:  loss 1.38426, acc 0.5166
# Epoch 58, CIFAR-10 Batch 5:  loss 1.38899, acc 0.5084
# Epoch 59, CIFAR-10 Batch 1:  loss 1.40226, acc 0.5058
# Epoch 59, CIFAR-10 Batch 2:  loss 1.38815, acc 0.5056
# Epoch 59, CIFAR-10 Batch 3:  loss 1.40156, acc 0.498
# Epoch 59, CIFAR-10 Batch 4:  loss 1.38834, acc 0.5124
# Epoch 59, CIFAR-10 Batch 5:  loss 1.38394, acc 0.5108
# Epoch 60, CIFAR-10 Batch 1:  loss 1.38973, acc 0.509
# Epoch 60, CIFAR-10 Batch 2:  loss 1.389, acc 0.5088
# Epoch 60, CIFAR-10 Batch 3:  loss 1.40052, acc 0.5008
# Epoch 60, CIFAR-10 Batch 4:  loss 1.37858, acc 0.515
# Epoch 60, CIFAR-10 Batch 5:  loss 1.4058, acc 0.5042
# Epoch 61, CIFAR-10 Batch 1:  loss 1.40074, acc 0.5076
# Epoch 61, CIFAR-10 Batch 2:  loss 1.3931, acc 0.5082
# Epoch 61, CIFAR-10 Batch 3:  loss 1.39167, acc 0.5054
# Epoch 61, CIFAR-10 Batch 4:  loss 1.395, acc 0.5126
# Epoch 61, CIFAR-10 Batch 5:  loss 1.38355, acc 0.512
# Epoch 62, CIFAR-10 Batch 1:  loss 1.41058, acc 0.5012
# Epoch 62, CIFAR-10 Batch 2:  loss 1.3946, acc 0.5046
# Epoch 62, CIFAR-10 Batch 3:  loss 1.3995, acc 0.5006
# Epoch 62, CIFAR-10 Batch 4:  loss 1.37361, acc 0.5148
# Epoch 62, CIFAR-10 Batch 5:  loss 1.37779, acc 0.514
# Epoch 63, CIFAR-10 Batch 1:  loss 1.39258, acc 0.5146
# Epoch 63, CIFAR-10 Batch 2:  loss 1.38184, acc 0.513
# Epoch 63, CIFAR-10 Batch 3:  loss 1.38553, acc 0.5074
# Epoch 63, CIFAR-10 Batch 4:  loss 1.37017, acc 0.5202
# Epoch 63, CIFAR-10 Batch 5:  loss 1.38292, acc 0.512
# Epoch 64, CIFAR-10 Batch 1:  loss 1.39226, acc 0.5124
# Epoch 64, CIFAR-10 Batch 2:  loss 1.38959, acc 0.5048
# Epoch 64, CIFAR-10 Batch 3:  loss 1.37056, acc 0.5156
# Epoch 64, CIFAR-10 Batch 4:  loss 1.37171, acc 0.5148
# Epoch 64, CIFAR-10 Batch 5:  loss 1.3703, acc 0.5192
# Epoch 65, CIFAR-10 Batch 1:  loss 1.40083, acc 0.51
# Epoch 65, CIFAR-10 Batch 2:  loss 1.37863, acc 0.506
# Epoch 65, CIFAR-10 Batch 3:  loss 1.37839, acc 0.5094
# Epoch 65, CIFAR-10 Batch 4:  loss 1.38361, acc 0.5164
# Epoch 65, CIFAR-10 Batch 5:  loss 1.37524, acc 0.5206
# Epoch 66, CIFAR-10 Batch 1:  loss 1.39591, acc 0.5096
# Epoch 66, CIFAR-10 Batch 2:  loss 1.37299, acc 0.5104
# Epoch 66, CIFAR-10 Batch 3:  loss 1.37636, acc 0.5128
# Epoch 66, CIFAR-10 Batch 4:  loss 1.37449, acc 0.5182
# Epoch 66, CIFAR-10 Batch 5:  loss 1.3735, acc 0.515
# Epoch 67, CIFAR-10 Batch 1:  loss 1.40378, acc 0.5032
# Epoch 67, CIFAR-10 Batch 2:  loss 1.37834, acc 0.5106
# Epoch 67, CIFAR-10 Batch 3:  loss 1.38554, acc 0.509
# Epoch 67, CIFAR-10 Batch 4:  loss 1.36573, acc 0.5236
# Epoch 67, CIFAR-10 Batch 5:  loss 1.37865, acc 0.513
# Epoch 68, CIFAR-10 Batch 1:  loss 1.4012, acc 0.5058
# Epoch 68, CIFAR-10 Batch 2:  loss 1.38275, acc 0.5044
# Epoch 68, CIFAR-10 Batch 3:  loss 1.39696, acc 0.502
# Epoch 68, CIFAR-10 Batch 4:  loss 1.3709, acc 0.5214
# Epoch 68, CIFAR-10 Batch 5:  loss 1.38459, acc 0.5074
# Epoch 69, CIFAR-10 Batch 1:  loss 1.40689, acc 0.5032
# Epoch 69, CIFAR-10 Batch 2:  loss 1.37974, acc 0.5068
# Epoch 69, CIFAR-10 Batch 3:  loss 1.37381, acc 0.5124
# Epoch 69, CIFAR-10 Batch 4:  loss 1.37429, acc 0.5192
# Epoch 69, CIFAR-10 Batch 5:  loss 1.38464, acc 0.5104
# Epoch 70, CIFAR-10 Batch 1:  loss 1.40693, acc 0.5072
# Epoch 70, CIFAR-10 Batch 2:  loss 1.37288, acc 0.5122
# Epoch 70, CIFAR-10 Batch 3:  loss 1.38809, acc 0.5028
# Epoch 70, CIFAR-10 Batch 4:  loss 1.36865, acc 0.5212
# Epoch 70, CIFAR-10 Batch 5:  loss 1.37238, acc 0.5156
# Epoch 71, CIFAR-10 Batch 1:  loss 1.40064, acc 0.5086
# Epoch 71, CIFAR-10 Batch 2:  loss 1.38166, acc 0.5098
# Epoch 71, CIFAR-10 Batch 3:  loss 1.37633, acc 0.5084
# Epoch 71, CIFAR-10 Batch 4:  loss 1.3683, acc 0.5204
# Epoch 71, CIFAR-10 Batch 5:  loss 1.38199, acc 0.5066
# Epoch 72, CIFAR-10 Batch 1:  loss 1.40374, acc 0.5038
# Epoch 72, CIFAR-10 Batch 2:  loss 1.37915, acc 0.5086
# Epoch 72, CIFAR-10 Batch 3:  loss 1.3714, acc 0.5124
# Epoch 72, CIFAR-10 Batch 4:  loss 1.36606, acc 0.5212
# Epoch 72, CIFAR-10 Batch 5:  loss 1.37255, acc 0.518
# Epoch 73, CIFAR-10 Batch 1:  loss 1.41758, acc 0.5058
# Epoch 73, CIFAR-10 Batch 2:  loss 1.39379, acc 0.5004
# Epoch 73, CIFAR-10 Batch 3:  loss 1.38521, acc 0.5068
# Epoch 73, CIFAR-10 Batch 4:  loss 1.36409, acc 0.522
# Epoch 73, CIFAR-10 Batch 5:  loss 1.38078, acc 0.5128
# Epoch 74, CIFAR-10 Batch 1:  loss 1.39672, acc 0.5094
# Epoch 74, CIFAR-10 Batch 2:  loss 1.37211, acc 0.508
# Epoch 74, CIFAR-10 Batch 3:  loss 1.36801, acc 0.514
# Epoch 74, CIFAR-10 Batch 4:  loss 1.36841, acc 0.525
# Epoch 74, CIFAR-10 Batch 5:  loss 1.37945, acc 0.5146
# Epoch 75, CIFAR-10 Batch 1:  loss 1.39941, acc 0.5058
# Epoch 75, CIFAR-10 Batch 2:  loss 1.38314, acc 0.5098
# Epoch 75, CIFAR-10 Batch 3:  loss 1.36859, acc 0.5176
# Epoch 75, CIFAR-10 Batch 4:  loss 1.36974, acc 0.52
# Epoch 75, CIFAR-10 Batch 5:  loss 1.39191, acc 0.5072
# Epoch 76, CIFAR-10 Batch 1:  loss 1.38786, acc 0.5144
# Epoch 76, CIFAR-10 Batch 2:  loss 1.38113, acc 0.5074
# Epoch 76, CIFAR-10 Batch 3:  loss 1.37325, acc 0.5132
# Epoch 76, CIFAR-10 Batch 4:  loss 1.37078, acc 0.5192
# Epoch 76, CIFAR-10 Batch 5:  loss 1.40075, acc 0.5052
# Epoch 77, CIFAR-10 Batch 1:  loss 1.41619, acc 0.5028
# Epoch 77, CIFAR-10 Batch 2:  loss 1.3794, acc 0.5062
# Epoch 77, CIFAR-10 Batch 3:  loss 1.37608, acc 0.5092
# Epoch 77, CIFAR-10 Batch 4:  loss 1.3616, acc 0.5248
# Epoch 77, CIFAR-10 Batch 5:  loss 1.37374, acc 0.5218
# Epoch 78, CIFAR-10 Batch 1:  loss 1.39511, acc 0.5076
# Epoch 78, CIFAR-10 Batch 2:  loss 1.38164, acc 0.5064
# Epoch 78, CIFAR-10 Batch 3:  loss 1.37052, acc 0.5182
# Epoch 78, CIFAR-10 Batch 4:  loss 1.35901, acc 0.5246
# Epoch 78, CIFAR-10 Batch 5:  loss 1.38658, acc 0.508
# Epoch 79, CIFAR-10 Batch 1:  loss 1.3886, acc 0.5128
# Epoch 79, CIFAR-10 Batch 2:  loss 1.38841, acc 0.5036
# Epoch 79, CIFAR-10 Batch 3:  loss 1.37351, acc 0.5126
# Epoch 79, CIFAR-10 Batch 4:  loss 1.36532, acc 0.5264
# Epoch 79, CIFAR-10 Batch 5:  loss 1.37407, acc 0.513
# Epoch 80, CIFAR-10 Batch 1:  loss 1.37434, acc 0.5162
# Epoch 80, CIFAR-10 Batch 2:  loss 1.38594, acc 0.504
# Epoch 80, CIFAR-10 Batch 3:  loss 1.36206, acc 0.5198
# Epoch 80, CIFAR-10 Batch 4:  loss 1.3537, acc 0.5254
# Epoch 80, CIFAR-10 Batch 5:  loss 1.38831, acc 0.5036
# Epoch 81, CIFAR-10 Batch 1:  loss 1.38909, acc 0.5076
# Epoch 81, CIFAR-10 Batch 2:  loss 1.39563, acc 0.499
# Epoch 81, CIFAR-10 Batch 3:  loss 1.36777, acc 0.5124
# Epoch 81, CIFAR-10 Batch 4:  loss 1.36267, acc 0.5254
# Epoch 81, CIFAR-10 Batch 5:  loss 1.3681, acc 0.517
# Epoch 82, CIFAR-10 Batch 1:  loss 1.38009, acc 0.5142
# Epoch 82, CIFAR-10 Batch 2:  loss 1.39274, acc 0.5024
# Epoch 82, CIFAR-10 Batch 3:  loss 1.36333, acc 0.5168
# Epoch 82, CIFAR-10 Batch 4:  loss 1.36414, acc 0.5256
# Epoch 82, CIFAR-10 Batch 5:  loss 1.3695, acc 0.5164
# Epoch 83, CIFAR-10 Batch 1:  loss 1.38609, acc 0.5126
# Epoch 83, CIFAR-10 Batch 2:  loss 1.39489, acc 0.5018
# Epoch 83, CIFAR-10 Batch 3:  loss 1.3603, acc 0.5172
# Epoch 83, CIFAR-10 Batch 4:  loss 1.35109, acc 0.5276
# Epoch 83, CIFAR-10 Batch 5:  loss 1.37226, acc 0.5098
# Epoch 84, CIFAR-10 Batch 1:  loss 1.40145, acc 0.5028
# Epoch 84, CIFAR-10 Batch 2:  loss 1.37871, acc 0.5102
# Epoch 84, CIFAR-10 Batch 3:  loss 1.36495, acc 0.517
# Epoch 84, CIFAR-10 Batch 4:  loss 1.35574, acc 0.5288
# Epoch 84, CIFAR-10 Batch 5:  loss 1.37784, acc 0.5136
# Epoch 85, CIFAR-10 Batch 1:  loss 1.38763, acc 0.513
# Epoch 85, CIFAR-10 Batch 2:  loss 1.37531, acc 0.5074
# Epoch 85, CIFAR-10 Batch 3:  loss 1.36552, acc 0.516
# Epoch 85, CIFAR-10 Batch 4:  loss 1.36279, acc 0.5196
# Epoch 85, CIFAR-10 Batch 5:  loss 1.38103, acc 0.5088
# Epoch 86, CIFAR-10 Batch 1:  loss 1.38083, acc 0.515
# Epoch 86, CIFAR-10 Batch 2:  loss 1.36794, acc 0.507
# Epoch 86, CIFAR-10 Batch 3:  loss 1.36172, acc 0.5198
# Epoch 86, CIFAR-10 Batch 4:  loss 1.36291, acc 0.5246
# Epoch 86, CIFAR-10 Batch 5:  loss 1.37121, acc 0.5146
# Epoch 87, CIFAR-10 Batch 1:  loss 1.38066, acc 0.513
# Epoch 87, CIFAR-10 Batch 2:  loss 1.38668, acc 0.5074
# Epoch 87, CIFAR-10 Batch 3:  loss 1.37243, acc 0.5148
# Epoch 87, CIFAR-10 Batch 4:  loss 1.3584, acc 0.525
# Epoch 87, CIFAR-10 Batch 5:  loss 1.37295, acc 0.5176
# Epoch 88, CIFAR-10 Batch 1:  loss 1.38151, acc 0.5132
# Epoch 88, CIFAR-10 Batch 2:  loss 1.37252, acc 0.5126
# Epoch 88, CIFAR-10 Batch 3:  loss 1.37378, acc 0.515
# Epoch 88, CIFAR-10 Batch 4:  loss 1.35284, acc 0.5262
# Epoch 88, CIFAR-10 Batch 5:  loss 1.36437, acc 0.5198
# Epoch 89, CIFAR-10 Batch 1:  loss 1.37493, acc 0.5154
# Epoch 89, CIFAR-10 Batch 2:  loss 1.36159, acc 0.5128
# Epoch 89, CIFAR-10 Batch 3:  loss 1.36889, acc 0.5142
# Epoch 89, CIFAR-10 Batch 4:  loss 1.35208, acc 0.526
# Epoch 89, CIFAR-10 Batch 5:  loss 1.3673, acc 0.5186
# Epoch 90, CIFAR-10 Batch 1:  loss 1.39629, acc 0.5142
# Epoch 90, CIFAR-10 Batch 2:  loss 1.36917, acc 0.5086
# Epoch 90, CIFAR-10 Batch 3:  loss 1.35862, acc 0.518
# Epoch 90, CIFAR-10 Batch 4:  loss 1.35397, acc 0.525
# Epoch 90, CIFAR-10 Batch 5:  loss 1.35592, acc 0.525
# Epoch 91, CIFAR-10 Batch 1:  loss 1.37572, acc 0.5144
# Epoch 91, CIFAR-10 Batch 2:  loss 1.37222, acc 0.5084
# Epoch 91, CIFAR-10 Batch 3:  loss 1.36113, acc 0.5186
# Epoch 91, CIFAR-10 Batch 4:  loss 1.35792, acc 0.5262
# Epoch 91, CIFAR-10 Batch 5:  loss 1.35941, acc 0.5244
# Epoch 92, CIFAR-10 Batch 1:  loss 1.37627, acc 0.513
# Epoch 92, CIFAR-10 Batch 2:  loss 1.38268, acc 0.5016
# Epoch 92, CIFAR-10 Batch 3:  loss 1.36818, acc 0.517
# Epoch 92, CIFAR-10 Batch 4:  loss 1.36263, acc 0.5242
# Epoch 92, CIFAR-10 Batch 5:  loss 1.36872, acc 0.5146
# Epoch 93, CIFAR-10 Batch 1:  loss 1.37068, acc 0.5154
# Epoch 93, CIFAR-10 Batch 2:  loss 1.36934, acc 0.508
# Epoch 93, CIFAR-10 Batch 3:  loss 1.36585, acc 0.5204
# Epoch 93, CIFAR-10 Batch 4:  loss 1.36803, acc 0.5206
# Epoch 93, CIFAR-10 Batch 5:  loss 1.36441, acc 0.5198
# Epoch 94, CIFAR-10 Batch 1:  loss 1.3736, acc 0.517
# Epoch 94, CIFAR-10 Batch 2:  loss 1.36677, acc 0.5128
# Epoch 94, CIFAR-10 Batch 3:  loss 1.36883, acc 0.516
# Epoch 94, CIFAR-10 Batch 4:  loss 1.35334, acc 0.5266
# Epoch 94, CIFAR-10 Batch 5:  loss 1.37248, acc 0.513
# Epoch 95, CIFAR-10 Batch 1:  loss 1.36641, acc 0.5188
# Epoch 95, CIFAR-10 Batch 2:  loss 1.35965, acc 0.5128
# Epoch 95, CIFAR-10 Batch 3:  loss 1.36073, acc 0.5156
# Epoch 95, CIFAR-10 Batch 4:  loss 1.35891, acc 0.5256
# Epoch 95, CIFAR-10 Batch 5:  loss 1.36351, acc 0.519
# Epoch 96, CIFAR-10 Batch 1:  loss 1.37133, acc 0.5188
# Epoch 96, CIFAR-10 Batch 2:  loss 1.37752, acc 0.508
# Epoch 96, CIFAR-10 Batch 3:  loss 1.37975, acc 0.5104
# Epoch 96, CIFAR-10 Batch 4:  loss 1.35698, acc 0.5216
# Epoch 96, CIFAR-10 Batch 5:  loss 1.36654, acc 0.5172
# Epoch 97, CIFAR-10 Batch 1:  loss 1.36389, acc 0.5216
# Epoch 97, CIFAR-10 Batch 2:  loss 1.36556, acc 0.5092
# Epoch 97, CIFAR-10 Batch 3:  loss 1.36319, acc 0.5174
# Epoch 97, CIFAR-10 Batch 4:  loss 1.35414, acc 0.5236
# Epoch 97, CIFAR-10 Batch 5:  loss 1.35544, acc 0.5222
# Epoch 98, CIFAR-10 Batch 1:  loss 1.35591, acc 0.5266
# Epoch 98, CIFAR-10 Batch 2:  loss 1.36842, acc 0.5064
# Epoch 98, CIFAR-10 Batch 3:  loss 1.36762, acc 0.5102
# Epoch 98, CIFAR-10 Batch 4:  loss 1.35081, acc 0.5254
# Epoch 98, CIFAR-10 Batch 5:  loss 1.35726, acc 0.5206
# Epoch 99, CIFAR-10 Batch 1:  loss 1.36646, acc 0.519
# Epoch 99, CIFAR-10 Batch 2:  loss 1.3744, acc 0.5096
# Epoch 99, CIFAR-10 Batch 3:  loss 1.35755, acc 0.5166
# Epoch 99, CIFAR-10 Batch 4:  loss 1.35093, acc 0.5264
# Epoch 99, CIFAR-10 Batch 5:  loss 1.34934, acc 0.524
# Epoch 100, CIFAR-10 Batch 1:  loss 1.37453, acc 0.5204
# Epoch 100, CIFAR-10 Batch 2:  loss 1.36286, acc 0.5138
# Epoch 100, CIFAR-10 Batch 3:  loss 1.35468, acc 0.5182
# Epoch 100, CIFAR-10 Batch 4:  loss 1.35692, acc 0.527
# Epoch 100, CIFAR-10 Batch 5:  loss 1.36213, acc 0.5232
# Epoch 101, CIFAR-10 Batch 1:  loss 1.36476, acc 0.5208
# Epoch 101, CIFAR-10 Batch 2:  loss 1.36373, acc 0.5094
# Epoch 101, CIFAR-10 Batch 3:  loss 1.36163, acc 0.5164
# Epoch 101, CIFAR-10 Batch 4:  loss 1.35855, acc 0.5228
# Epoch 101, CIFAR-10 Batch 5:  loss 1.35965, acc 0.5246
# Epoch 102, CIFAR-10 Batch 1:  loss 1.35636, acc 0.5212
# Epoch 102, CIFAR-10 Batch 2:  loss 1.36314, acc 0.511
# Epoch 102, CIFAR-10 Batch 3:  loss 1.36381, acc 0.5162
# Epoch 102, CIFAR-10 Batch 4:  loss 1.36862, acc 0.5218
# Epoch 102, CIFAR-10 Batch 5:  loss 1.36494, acc 0.5142
# Epoch 103, CIFAR-10 Batch 1:  loss 1.37422, acc 0.5164
# Epoch 103, CIFAR-10 Batch 2:  loss 1.36518, acc 0.5054
# Epoch 103, CIFAR-10 Batch 3:  loss 1.35365, acc 0.5196
# Epoch 103, CIFAR-10 Batch 4:  loss 1.35257, acc 0.5246
# Epoch 103, CIFAR-10 Batch 5:  loss 1.35626, acc 0.5218
# Epoch 104, CIFAR-10 Batch 1:  loss 1.36929, acc 0.523
# Epoch 104, CIFAR-10 Batch 2:  loss 1.36662, acc 0.5104
# Epoch 104, CIFAR-10 Batch 3:  loss 1.35185, acc 0.5202
# Epoch 104, CIFAR-10 Batch 4:  loss 1.35588, acc 0.5206
# Epoch 104, CIFAR-10 Batch 5:  loss 1.3572, acc 0.5216
# Epoch 105, CIFAR-10 Batch 1:  loss 1.36344, acc 0.5226
# Epoch 105, CIFAR-10 Batch 2:  loss 1.35997, acc 0.5144
# Epoch 105, CIFAR-10 Batch 3:  loss 1.35282, acc 0.5206
# Epoch 105, CIFAR-10 Batch 4:  loss 1.35454, acc 0.5228
# Epoch 105, CIFAR-10 Batch 5:  loss 1.36573, acc 0.5146
# Epoch 106, CIFAR-10 Batch 1:  loss 1.36575, acc 0.5232
# Epoch 106, CIFAR-10 Batch 2:  loss 1.35714, acc 0.5154
# Epoch 106, CIFAR-10 Batch 3:  loss 1.35456, acc 0.52
# Epoch 106, CIFAR-10 Batch 4:  loss 1.3449, acc 0.5244
# Epoch 106, CIFAR-10 Batch 5:  loss 1.36569, acc 0.519
# Epoch 107, CIFAR-10 Batch 1:  loss 1.37399, acc 0.518
# Epoch 107, CIFAR-10 Batch 2:  loss 1.35503, acc 0.5142
# Epoch 107, CIFAR-10 Batch 3:  loss 1.36376, acc 0.5172
# Epoch 107, CIFAR-10 Batch 4:  loss 1.35173, acc 0.5252
# Epoch 107, CIFAR-10 Batch 5:  loss 1.35334, acc 0.5222
# Epoch 108, CIFAR-10 Batch 1:  loss 1.35152, acc 0.526
# Epoch 108, CIFAR-10 Batch 2:  loss 1.36098, acc 0.5114
# Epoch 108, CIFAR-10 Batch 3:  loss 1.34845, acc 0.5226
# Epoch 108, CIFAR-10 Batch 4:  loss 1.34939, acc 0.53
# Epoch 108, CIFAR-10 Batch 5:  loss 1.36399, acc 0.5152
# Epoch 109, CIFAR-10 Batch 1:  loss 1.35806, acc 0.5256
# Epoch 109, CIFAR-10 Batch 2:  loss 1.35953, acc 0.5128
# Epoch 109, CIFAR-10 Batch 3:  loss 1.34904, acc 0.5196
# Epoch 109, CIFAR-10 Batch 4:  loss 1.3533, acc 0.5244
# Epoch 109, CIFAR-10 Batch 5:  loss 1.36897, acc 0.5132
# Epoch 110, CIFAR-10 Batch 1:  loss 1.34195, acc 0.5304
# Epoch 110, CIFAR-10 Batch 2:  loss 1.3655, acc 0.5114
# Epoch 110, CIFAR-10 Batch 3:  loss 1.3627, acc 0.516
# Epoch 110, CIFAR-10 Batch 4:  loss 1.37536, acc 0.5188
# Epoch 110, CIFAR-10 Batch 5:  loss 1.35766, acc 0.5168
# Epoch 111, CIFAR-10 Batch 1:  loss 1.35195, acc 0.5264
# Epoch 111, CIFAR-10 Batch 2:  loss 1.36146, acc 0.5146
# Epoch 111, CIFAR-10 Batch 3:  loss 1.36528, acc 0.5164
# Epoch 111, CIFAR-10 Batch 4:  loss 1.35538, acc 0.5228
# Epoch 111, CIFAR-10 Batch 5:  loss 1.35251, acc 0.5232
# Epoch 112, CIFAR-10 Batch 1:  loss 1.35184, acc 0.5264
# Epoch 112, CIFAR-10 Batch 2:  loss 1.35543, acc 0.515
# Epoch 112, CIFAR-10 Batch 3:  loss 1.35945, acc 0.5194
# Epoch 112, CIFAR-10 Batch 4:  loss 1.36006, acc 0.5194
# Epoch 112, CIFAR-10 Batch 5:  loss 1.36442, acc 0.5148
# Epoch 113, CIFAR-10 Batch 1:  loss 1.34832, acc 0.53
# Epoch 113, CIFAR-10 Batch 2:  loss 1.35511, acc 0.5136
# Epoch 113, CIFAR-10 Batch 3:  loss 1.35466, acc 0.5212
# Epoch 113, CIFAR-10 Batch 4:  loss 1.35, acc 0.5258
# Epoch 113, CIFAR-10 Batch 5:  loss 1.3474, acc 0.5266
# Epoch 114, CIFAR-10 Batch 1:  loss 1.34168, acc 0.5322
# Epoch 114, CIFAR-10 Batch 2:  loss 1.35745, acc 0.5132
# Epoch 114, CIFAR-10 Batch 3:  loss 1.35156, acc 0.5212
# Epoch 114, CIFAR-10 Batch 4:  loss 1.35282, acc 0.523
# Epoch 114, CIFAR-10 Batch 5:  loss 1.36556, acc 0.5192
# Epoch 115, CIFAR-10 Batch 1:  loss 1.34722, acc 0.5314
# Epoch 115, CIFAR-10 Batch 2:  loss 1.36627, acc 0.5124
# Epoch 115, CIFAR-10 Batch 3:  loss 1.34605, acc 0.5254
# Epoch 115, CIFAR-10 Batch 4:  loss 1.33955, acc 0.5264
# Epoch 115, CIFAR-10 Batch 5:  loss 1.36015, acc 0.521
# Epoch 116, CIFAR-10 Batch 1:  loss 1.34112, acc 0.5304
# Epoch 116, CIFAR-10 Batch 2:  loss 1.36007, acc 0.5162
# Epoch 116, CIFAR-10 Batch 3:  loss 1.35274, acc 0.5232
# Epoch 116, CIFAR-10 Batch 4:  loss 1.34659, acc 0.5318
# Epoch 116, CIFAR-10 Batch 5:  loss 1.35902, acc 0.52
# Epoch 117, CIFAR-10 Batch 1:  loss 1.34458, acc 0.528
# Epoch 117, CIFAR-10 Batch 2:  loss 1.36302, acc 0.5134
# Epoch 117, CIFAR-10 Batch 3:  loss 1.35098, acc 0.5244
# Epoch 117, CIFAR-10 Batch 4:  loss 1.34014, acc 0.5284
# Epoch 117, CIFAR-10 Batch 5:  loss 1.35016, acc 0.5204
# Epoch 118, CIFAR-10 Batch 1:  loss 1.36279, acc 0.5302
# Epoch 118, CIFAR-10 Batch 2:  loss 1.35984, acc 0.5128
# Epoch 118, CIFAR-10 Batch 3:  loss 1.35481, acc 0.5206
# Epoch 118, CIFAR-10 Batch 4:  loss 1.35871, acc 0.522
# Epoch 118, CIFAR-10 Batch 5:  loss 1.34902, acc 0.5216
# Epoch 119, CIFAR-10 Batch 1:  loss 1.34937, acc 0.5274
# Epoch 119, CIFAR-10 Batch 2:  loss 1.36029, acc 0.5146
# Epoch 119, CIFAR-10 Batch 3:  loss 1.36272, acc 0.5178
# Epoch 119, CIFAR-10 Batch 4:  loss 1.35091, acc 0.5222
# Epoch 119, CIFAR-10 Batch 5:  loss 1.3499, acc 0.5252
# Epoch 120, CIFAR-10 Batch 1:  loss 1.33875, acc 0.5334
# Epoch 120, CIFAR-10 Batch 2:  loss 1.35538, acc 0.513
# Epoch 120, CIFAR-10 Batch 3:  loss 1.3528, acc 0.5208
# Epoch 120, CIFAR-10 Batch 4:  loss 1.33718, acc 0.528
# Epoch 120, CIFAR-10 Batch 5:  loss 1.34342, acc 0.5248

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.51923828125

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
