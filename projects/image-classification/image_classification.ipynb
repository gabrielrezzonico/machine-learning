# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %%
# Explore the dataset
batch_id = 2
sample_id = 111
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 111:
# Image - Min Value: 21 Max Value: 235
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(raw_image):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return np.array(raw_image, dtype=float) / 255.0


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(labels):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # find the number of classes
    num_classes = np.max(labels) + 1

    return np.eye(num_classes)[labels]
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    print(image_shape)
    return tf.placeholder(tf.float32, shape=(None, image_shape[0], image_shape[1], image_shape[2]), name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, shape=(None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# (32, 32, 3)
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    print(x_tensor)
    shape = x_tensor.get_shape().as_list()
    print(shape)
    print(shape[3])
    num_channels = shape[3]
    print(conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    
    #weights = tf.Variable(tf.random_normal([2, 2, 5, 10]))
    weights = tf.Variable(tf.random_normal([conv_ksize[0], conv_ksize[1], num_channels, conv_num_outputs]))
    
    biases = tf.Variable(tf.constant(1.0, shape=[conv_num_outputs]), name='Bias1')

    #conv = tf.nn.conv2d(x_tensor, weights, [1, 4, 4, 1], 'SAME', name='Conv2d_1')
    conv = tf.nn.conv2d(x_tensor, weights, [1, conv_strides[0], conv_strides[1], 1], 'SAME', name='Conv2d_1')
    
    hidden = tf.nn.relu(conv + biases)
    
    sub = tf.nn.max_pool(hidden, [1, pool_ksize[0], pool_ksize[1], 1], [1, pool_strides[0], pool_strides[1], 1], 'SAME', name='max_pool_1')
    
    return sub 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tensor("Placeholder:0", shape=(?, 32, 32, 5), dtype=float32)
# [None, 32, 32, 5]
# 5
# 10 (2, 2) (4, 4) (2, 2) (2, 2)
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    print(tf.contrib.layers.flatten(x_tensor))
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tensor("Flatten/Reshape:0", shape=(?, 1800), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    print(x_tensor)
    print(num_outputs)
    shape = x_tensor.get_shape().as_list()
    print(shape[1])

    weights = tf.Variable(tf.random_normal([shape[1], num_outputs]))
    bias = tf.Variable(tf.constant(1.0, shape=[num_outputs]))
    return tf.matmul(x_tensor, weights) + bias


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tensor("Placeholder_2:0", shape=(?, 128), dtype=float32)
# 40
# 128
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    print(x_tensor)
    print(num_outputs)
    shape = x_tensor.get_shape().as_list()
    print(shape[1])
    weights = tf.Variable(tf.random_normal([shape[1], num_outputs]))
    bias = tf.Variable(tf.constant(1.0, shape=[num_outputs]))
    print(tf.matmul(x_tensor, weights) + bias)
    return tf.matmul(x_tensor, weights) + bias


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tensor("Placeholder_3:0", shape=(?, 128), dtype=float32)
# 40
# 128
# Tensor("add_2:0", shape=(?, 40), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x_tensor, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    
    print (x_tensor)
    print(keep_prob)
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    #10 (2, 2) (4, 4) (2, 2) (2, 2)
    #conv = conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv = conv2d_maxpool(x_tensor, 40, (2, 2), (4, 4), (2, 2), (2, 2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat = flatten(conv)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully = fully_conn(flat, 10)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(fully, 10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# (32, 32, 3)
# Tensor("x:0", shape=(?, 32, 32, 3), dtype=float32)
# Tensor("keep_prob:0", dtype=float32)
# Tensor("x:0", shape=(?, 32, 32, 3), dtype=float32)
# [None, 32, 32, 3]
# 3
# 40 (2, 2) (4, 4) (2, 2) (2, 2)
# Tensor("Flatten/Reshape:0", shape=(?, 640), dtype=float32)
# Tensor("Flatten_1/Reshape:0", shape=(?, 640), dtype=float32)
# 10
# 640
# Tensor("add_1:0", shape=(?, 10), dtype=float32)
# 10
# 10
# Tensor("add_2:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 32, 32, 3), dtype=float32)
# Tensor("Placeholder_1:0", dtype=float32)
# Tensor("Placeholder:0", shape=(?, 32, 32, 3), dtype=float32)
# [None, 32, 32, 3]
# 3
# 40 (2, 2) (4, 4) (2, 2) (2, 2)
# Tensor("Flatten_2/Reshape:0", shape=(?, 640), dtype=float32)
# Tensor("Flatten_3/Reshape:0", shape=(?, 640), dtype=float32)
# 10
# 640
# Tensor("add_5:0", shape=(?, 10), dtype=float32)
# 10
# 10
# Tensor("add_6:0", shape=(?, 10), dtype=float32)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    feed_dict = {
        keep_prob: keep_probability, 
        x: feature_batch,
        y: label_batch
    }
    session.run( [ optimizer], feed_dict)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """

    feed_dict = {
        keep_prob: 1, 
        x: feature_batch[:128],
        y: label_batch[:128]
    }
    c, a = session.run(
        [ cost, accuracy],
        feed_dict)

    print("loss {:g}, acc {:g}".format(c, a))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.8

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    #sess.run(tf.global_variables_initializer())
    tf.initialize_all_variables().run()
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss 96.1439, acc 0.1
# Epoch  2, CIFAR-10 Batch 1:  loss 56.9421, acc 0.05
# Epoch  3, CIFAR-10 Batch 1:  loss 50.2033, acc 0.125
# Epoch  4, CIFAR-10 Batch 1:  loss 45.833, acc 0.125
# Epoch  5, CIFAR-10 Batch 1:  loss 42.9021, acc 0.125
# Epoch  6, CIFAR-10 Batch 1:  loss 40.5249, acc 0.1
# Epoch  7, CIFAR-10 Batch 1:  loss 38.1754, acc 0.1
# Epoch  8, CIFAR-10 Batch 1:  loss 36.2819, acc 0.15
# Epoch  9, CIFAR-10 Batch 1:  loss 34.6532, acc 0.15
# Epoch 10, CIFAR-10 Batch 1:  loss 32.9956, acc 0.15
# Epoch 11, CIFAR-10 Batch 1:  loss 31.5432, acc 0.175
# Epoch 12, CIFAR-10 Batch 1:  loss 30.2054, acc 0.175
# Epoch 13, CIFAR-10 Batch 1:  loss 28.883, acc 0.175
# Epoch 14, CIFAR-10 Batch 1:  loss 27.6486, acc 0.175
# Epoch 15, CIFAR-10 Batch 1:  loss 26.4517, acc 0.175
# Epoch 16, CIFAR-10 Batch 1:  loss 25.2658, acc 0.175
# Epoch 17, CIFAR-10 Batch 1:  loss 24.1708, acc 0.175
# Epoch 18, CIFAR-10 Batch 1:  loss 23.1379, acc 0.175
# Epoch 19, CIFAR-10 Batch 1:  loss 22.1742, acc 0.175
# Epoch 20, CIFAR-10 Batch 1:  loss 21.2632, acc 0.2
# Epoch 21, CIFAR-10 Batch 1:  loss 20.3862, acc 0.2
# Epoch 22, CIFAR-10 Batch 1:  loss 19.523, acc 0.2
# Epoch 23, CIFAR-10 Batch 1:  loss 18.6994, acc 0.2
# Epoch 24, CIFAR-10 Batch 1:  loss 17.8979, acc 0.225
# Epoch 25, CIFAR-10 Batch 1:  loss 17.1057, acc 0.225
# Epoch 26, CIFAR-10 Batch 1:  loss 16.3387, acc 0.225
# Epoch 27, CIFAR-10 Batch 1:  loss 15.6202, acc 0.225
# Epoch 28, CIFAR-10 Batch 1:  loss 14.9476, acc 0.225
# Epoch 29, CIFAR-10 Batch 1:  loss 14.3135, acc 0.25
# Epoch 30, CIFAR-10 Batch 1:  loss 13.7105, acc 0.25
# Epoch 31, CIFAR-10 Batch 1:  loss 13.1572, acc 0.25
# Epoch 32, CIFAR-10 Batch 1:  loss 12.6413, acc 0.25
# Epoch 33, CIFAR-10 Batch 1:  loss 12.1604, acc 0.25
# Epoch 34, CIFAR-10 Batch 1:  loss 11.6987, acc 0.25
# Epoch 35, CIFAR-10 Batch 1:  loss 11.2492, acc 0.225
# Epoch 36, CIFAR-10 Batch 1:  loss 10.8174, acc 0.225
# Epoch 37, CIFAR-10 Batch 1:  loss 10.4141, acc 0.225
# Epoch 38, CIFAR-10 Batch 1:  loss 10.0582, acc 0.225
# Epoch 39, CIFAR-10 Batch 1:  loss 9.72691, acc 0.25
# Epoch 40, CIFAR-10 Batch 1:  loss 9.41967, acc 0.25
# Epoch 41, CIFAR-10 Batch 1:  loss 9.12905, acc 0.25
# Epoch 42, CIFAR-10 Batch 1:  loss 8.85313, acc 0.25
# Epoch 43, CIFAR-10 Batch 1:  loss 8.58905, acc 0.25
# Epoch 44, CIFAR-10 Batch 1:  loss 8.33239, acc 0.25
# Epoch 45, CIFAR-10 Batch 1:  loss 8.0852, acc 0.25
# Epoch 46, CIFAR-10 Batch 1:  loss 7.85296, acc 0.25
# Epoch 47, CIFAR-10 Batch 1:  loss 7.62446, acc 0.275
# Epoch 48, CIFAR-10 Batch 1:  loss 7.40742, acc 0.275
# Epoch 49, CIFAR-10 Batch 1:  loss 7.20036, acc 0.275
# Epoch 50, CIFAR-10 Batch 1:  loss 7.00107, acc 0.275
# Epoch 51, CIFAR-10 Batch 1:  loss 6.8166, acc 0.3
# Epoch 52, CIFAR-10 Batch 1:  loss 6.63951, acc 0.3
# Epoch 53, CIFAR-10 Batch 1:  loss 6.46637, acc 0.325
# Epoch 54, CIFAR-10 Batch 1:  loss 6.29513, acc 0.325
# Epoch 55, CIFAR-10 Batch 1:  loss 6.12717, acc 0.325
# Epoch 56, CIFAR-10 Batch 1:  loss 5.96279, acc 0.325
# Epoch 57, CIFAR-10 Batch 1:  loss 5.80971, acc 0.325
# Epoch 58, CIFAR-10 Batch 1:  loss 5.66756, acc 0.325
# Epoch 59, CIFAR-10 Batch 1:  loss 5.53219, acc 0.325
# Epoch 60, CIFAR-10 Batch 1:  loss 5.4044, acc 0.325
# Epoch 61, CIFAR-10 Batch 1:  loss 5.28156, acc 0.325
# Epoch 62, CIFAR-10 Batch 1:  loss 5.16709, acc 0.325
# Epoch 63, CIFAR-10 Batch 1:  loss 5.05568, acc 0.325
# Epoch 64, CIFAR-10 Batch 1:  loss 4.94487, acc 0.325
# Epoch 65, CIFAR-10 Batch 1:  loss 4.82343, acc 0.325
# Epoch 66, CIFAR-10 Batch 1:  loss 4.69333, acc 0.325
# Epoch 67, CIFAR-10 Batch 1:  loss 4.559, acc 0.325
# Epoch 68, CIFAR-10 Batch 1:  loss 4.42776, acc 0.35
# Epoch 69, CIFAR-10 Batch 1:  loss 4.29718, acc 0.375
# Epoch 70, CIFAR-10 Batch 1:  loss 4.17619, acc 0.375
# Epoch 71, CIFAR-10 Batch 1:  loss 4.05899, acc 0.375
# Epoch 72, CIFAR-10 Batch 1:  loss 3.94963, acc 0.375
# Epoch 73, CIFAR-10 Batch 1:  loss 3.84677, acc 0.375
# Epoch 74, CIFAR-10 Batch 1:  loss 3.73648, acc 0.375
# Epoch 75, CIFAR-10 Batch 1:  loss 3.63207, acc 0.4
# Epoch 76, CIFAR-10 Batch 1:  loss 3.52944, acc 0.425
# Epoch 77, CIFAR-10 Batch 1:  loss 3.43632, acc 0.425
# Epoch 78, CIFAR-10 Batch 1:  loss 3.33944, acc 0.425
# Epoch 79, CIFAR-10 Batch 1:  loss 3.24919, acc 0.425
# Epoch 80, CIFAR-10 Batch 1:  loss 3.16434, acc 0.45
# Epoch 81, CIFAR-10 Batch 1:  loss 3.07985, acc 0.45
# Epoch 82, CIFAR-10 Batch 1:  loss 2.99437, acc 0.45
# Epoch 83, CIFAR-10 Batch 1:  loss 2.9192, acc 0.475
# Epoch 84, CIFAR-10 Batch 1:  loss 2.8536, acc 0.475
# Epoch 85, CIFAR-10 Batch 1:  loss 2.78929, acc 0.475
# Epoch 86, CIFAR-10 Batch 1:  loss 2.73122, acc 0.5
# Epoch 87, CIFAR-10 Batch 1:  loss 2.67926, acc 0.5
# Epoch 88, CIFAR-10 Batch 1:  loss 2.62835, acc 0.525
# Epoch 89, CIFAR-10 Batch 1:  loss 2.58431, acc 0.525
# Epoch 90, CIFAR-10 Batch 1:  loss 2.53956, acc 0.525
# Epoch 91, CIFAR-10 Batch 1:  loss 2.4978, acc 0.525
# Epoch 92, CIFAR-10 Batch 1:  loss 2.45896, acc 0.525
# Epoch 93, CIFAR-10 Batch 1:  loss 2.42155, acc 0.525
# Epoch 94, CIFAR-10 Batch 1:  loss 2.38566, acc 0.55
# Epoch 95, CIFAR-10 Batch 1:  loss 2.35044, acc 0.55
# Epoch 96, CIFAR-10 Batch 1:  loss 2.31684, acc 0.55
# Epoch 97, CIFAR-10 Batch 1:  loss 2.28575, acc 0.55
# Epoch 98, CIFAR-10 Batch 1:  loss 2.25517, acc 0.55
# Epoch 99, CIFAR-10 Batch 1:  loss 2.2261, acc 0.55
# Epoch 100, CIFAR-10 Batch 1:  loss 2.19841, acc 0.55

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    #sess.run(tf.global_variables_initializer())
    tf.initialize_all_variables().run()
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss 61.8291, acc 0.1
# Epoch  1, CIFAR-10 Batch 2:  loss 29.4451, acc 0.125
# Epoch  1, CIFAR-10 Batch 3:  loss 32.4512, acc 0.075
# Epoch  1, CIFAR-10 Batch 4:  loss 34.5718, acc 0.025
# Epoch  1, CIFAR-10 Batch 5:  loss 25.6822, acc 0.15
# Epoch  2, CIFAR-10 Batch 1:  loss 26.6891, acc 0.1
# Epoch  2, CIFAR-10 Batch 2:  loss 20.1365, acc 0.075
# Epoch  2, CIFAR-10 Batch 3:  loss 23.2474, acc 0.05
# Epoch  2, CIFAR-10 Batch 4:  loss 26.254, acc 0.05
# Epoch  2, CIFAR-10 Batch 5:  loss 19.8408, acc 0.25
# Epoch  3, CIFAR-10 Batch 1:  loss 20.4011, acc 0.1
# Epoch  3, CIFAR-10 Batch 2:  loss 14.8562, acc 0.15
# Epoch  3, CIFAR-10 Batch 3:  loss 17.496, acc 0.1
# Epoch  3, CIFAR-10 Batch 4:  loss 21.5773, acc 0.1
# Epoch  3, CIFAR-10 Batch 5:  loss 16.129, acc 0.325
# Epoch  4, CIFAR-10 Batch 1:  loss 16.1663, acc 0.15
# Epoch  4, CIFAR-10 Batch 2:  loss 12.1659, acc 0.175
# Epoch  4, CIFAR-10 Batch 3:  loss 14.0086, acc 0.15
# Epoch  4, CIFAR-10 Batch 4:  loss 18.631, acc 0.15
# Epoch  4, CIFAR-10 Batch 5:  loss 13.4757, acc 0.3
# Epoch  5, CIFAR-10 Batch 1:  loss 13.3415, acc 0.125
# Epoch  5, CIFAR-10 Batch 2:  loss 10.744, acc 0.225
# Epoch  5, CIFAR-10 Batch 3:  loss 11.6662, acc 0.175
# Epoch  5, CIFAR-10 Batch 4:  loss 16.3416, acc 0.125
# Epoch  5, CIFAR-10 Batch 5:  loss 11.3822, acc 0.25
# Epoch  6, CIFAR-10 Batch 1:  loss 11.2394, acc 0.125
# Epoch  6, CIFAR-10 Batch 2:  loss 9.79345, acc 0.225
# Epoch  6, CIFAR-10 Batch 3:  loss 9.95876, acc 0.2
# Epoch  6, CIFAR-10 Batch 4:  loss 14.0981, acc 0.175
# Epoch  6, CIFAR-10 Batch 5:  loss 9.77895, acc 0.275
# Epoch  7, CIFAR-10 Batch 1:  loss 9.83342, acc 0.175
# Epoch  7, CIFAR-10 Batch 2:  loss 9.11078, acc 0.225
# Epoch  7, CIFAR-10 Batch 3:  loss 8.60251, acc 0.175
# Epoch  7, CIFAR-10 Batch 4:  loss 11.9573, acc 0.2
# Epoch  7, CIFAR-10 Batch 5:  loss 8.48242, acc 0.3
# Epoch  8, CIFAR-10 Batch 1:  loss 8.67209, acc 0.2
# Epoch  8, CIFAR-10 Batch 2:  loss 8.41297, acc 0.225
# Epoch  8, CIFAR-10 Batch 3:  loss 7.68296, acc 0.175
# Epoch  8, CIFAR-10 Batch 4:  loss 10.2945, acc 0.2
# Epoch  8, CIFAR-10 Batch 5:  loss 7.72046, acc 0.275
# Epoch  9, CIFAR-10 Batch 1:  loss 7.69306, acc 0.25
# Epoch  9, CIFAR-10 Batch 2:  loss 7.62555, acc 0.2
# Epoch  9, CIFAR-10 Batch 3:  loss 7.10443, acc 0.2
# Epoch  9, CIFAR-10 Batch 4:  loss 8.94886, acc 0.2
# Epoch  9, CIFAR-10 Batch 5:  loss 7.04863, acc 0.25
# Epoch 10, CIFAR-10 Batch 1:  loss 6.88519, acc 0.275
# Epoch 10, CIFAR-10 Batch 2:  loss 6.88667, acc 0.225
# Epoch 10, CIFAR-10 Batch 3:  loss 6.60918, acc 0.175
# Epoch 10, CIFAR-10 Batch 4:  loss 7.90594, acc 0.175
# Epoch 10, CIFAR-10 Batch 5:  loss 6.40329, acc 0.225
# Epoch 11, CIFAR-10 Batch 1:  loss 6.14679, acc 0.3
# Epoch 11, CIFAR-10 Batch 2:  loss 6.22067, acc 0.225
# Epoch 11, CIFAR-10 Batch 3:  loss 6.07703, acc 0.175
# Epoch 11, CIFAR-10 Batch 4:  loss 7.06355, acc 0.175
# Epoch 11, CIFAR-10 Batch 5:  loss 5.84838, acc 0.25
# Epoch 12, CIFAR-10 Batch 1:  loss 5.484, acc 0.3
# Epoch 12, CIFAR-10 Batch 2:  loss 5.67257, acc 0.2
# Epoch 12, CIFAR-10 Batch 3:  loss 5.58697, acc 0.15
# Epoch 12, CIFAR-10 Batch 4:  loss 6.34557, acc 0.15
# Epoch 12, CIFAR-10 Batch 5:  loss 5.35987, acc 0.25
# Epoch 13, CIFAR-10 Batch 1:  loss 4.91743, acc 0.3
# Epoch 13, CIFAR-10 Batch 2:  loss 5.22315, acc 0.25
# Epoch 13, CIFAR-10 Batch 3:  loss 5.12377, acc 0.175
# Epoch 13, CIFAR-10 Batch 4:  loss 5.68132, acc 0.15
# Epoch 13, CIFAR-10 Batch 5:  loss 4.92692, acc 0.275
# Epoch 14, CIFAR-10 Batch 1:  loss 4.43316, acc 0.275
# Epoch 14, CIFAR-10 Batch 2:  loss 4.84907, acc 0.25
# Epoch 14, CIFAR-10 Batch 3:  loss 4.68894, acc 0.2
# Epoch 14, CIFAR-10 Batch 4:  loss 5.10934, acc 0.15
# Epoch 14, CIFAR-10 Batch 5:  loss 4.55858, acc 0.3
# Epoch 15, CIFAR-10 Batch 1:  loss 4.02471, acc 0.275
# Epoch 15, CIFAR-10 Batch 2:  loss 4.51643, acc 0.275
# Epoch 15, CIFAR-10 Batch 3:  loss 4.29312, acc 0.25
# Epoch 15, CIFAR-10 Batch 4:  loss 4.62244, acc 0.15
# Epoch 15, CIFAR-10 Batch 5:  loss 4.22953, acc 0.275
# Epoch 16, CIFAR-10 Batch 1:  loss 3.67148, acc 0.275
# Epoch 16, CIFAR-10 Batch 2:  loss 4.22151, acc 0.3
# Epoch 16, CIFAR-10 Batch 3:  loss 3.92384, acc 0.25
# Epoch 16, CIFAR-10 Batch 4:  loss 4.189, acc 0.15
# Epoch 16, CIFAR-10 Batch 5:  loss 3.93328, acc 0.3
# Epoch 17, CIFAR-10 Batch 1:  loss 3.37595, acc 0.275
# Epoch 17, CIFAR-10 Batch 2:  loss 3.97162, acc 0.325
# Epoch 17, CIFAR-10 Batch 3:  loss 3.58573, acc 0.225
# Epoch 17, CIFAR-10 Batch 4:  loss 3.84866, acc 0.15
# Epoch 17, CIFAR-10 Batch 5:  loss 3.67851, acc 0.325
# Epoch 18, CIFAR-10 Batch 1:  loss 3.12511, acc 0.275
# Epoch 18, CIFAR-10 Batch 2:  loss 3.74145, acc 0.35
# Epoch 18, CIFAR-10 Batch 3:  loss 3.30744, acc 0.225
# Epoch 18, CIFAR-10 Batch 4:  loss 3.54151, acc 0.15
# Epoch 18, CIFAR-10 Batch 5:  loss 3.45484, acc 0.325
# Epoch 19, CIFAR-10 Batch 1:  loss 2.91835, acc 0.25
# Epoch 19, CIFAR-10 Batch 2:  loss 3.5299, acc 0.325
# Epoch 19, CIFAR-10 Batch 3:  loss 3.05225, acc 0.225
# Epoch 19, CIFAR-10 Batch 4:  loss 3.28093, acc 0.175
# Epoch 19, CIFAR-10 Batch 5:  loss 3.26302, acc 0.325
# Epoch 20, CIFAR-10 Batch 1:  loss 2.74343, acc 0.275
# Epoch 20, CIFAR-10 Batch 2:  loss 3.3359, acc 0.325
# Epoch 20, CIFAR-10 Batch 3:  loss 2.82387, acc 0.275
# Epoch 20, CIFAR-10 Batch 4:  loss 3.06847, acc 0.175
# Epoch 20, CIFAR-10 Batch 5:  loss 3.0986, acc 0.325
# Epoch 21, CIFAR-10 Batch 1:  loss 2.5854, acc 0.275
# Epoch 21, CIFAR-10 Batch 2:  loss 3.15829, acc 0.325
# Epoch 21, CIFAR-10 Batch 3:  loss 2.61582, acc 0.275
# Epoch 21, CIFAR-10 Batch 4:  loss 2.88103, acc 0.175
# Epoch 21, CIFAR-10 Batch 5:  loss 2.94268, acc 0.325
# Epoch 22, CIFAR-10 Batch 1:  loss 2.45687, acc 0.275
# Epoch 22, CIFAR-10 Batch 2:  loss 2.99197, acc 0.325
# Epoch 22, CIFAR-10 Batch 3:  loss 2.4319, acc 0.225
# Epoch 22, CIFAR-10 Batch 4:  loss 2.71764, acc 0.15
# Epoch 22, CIFAR-10 Batch 5:  loss 2.79876, acc 0.325
# Epoch 23, CIFAR-10 Batch 1:  loss 2.36818, acc 0.275
# Epoch 23, CIFAR-10 Batch 2:  loss 2.84876, acc 0.35
# Epoch 23, CIFAR-10 Batch 3:  loss 2.27063, acc 0.225
# Epoch 23, CIFAR-10 Batch 4:  loss 2.56521, acc 0.15
# Epoch 23, CIFAR-10 Batch 5:  loss 2.67673, acc 0.325
# Epoch 24, CIFAR-10 Batch 1:  loss 2.28767, acc 0.3
# Epoch 24, CIFAR-10 Batch 2:  loss 2.719, acc 0.35
# Epoch 24, CIFAR-10 Batch 3:  loss 2.13895, acc 0.25
# Epoch 24, CIFAR-10 Batch 4:  loss 2.43198, acc 0.2
# Epoch 24, CIFAR-10 Batch 5:  loss 2.57559, acc 0.35
# Epoch 25, CIFAR-10 Batch 1:  loss 2.22849, acc 0.3
# Epoch 25, CIFAR-10 Batch 2:  loss 2.60521, acc 0.35
# Epoch 25, CIFAR-10 Batch 3:  loss 2.02641, acc 0.275
# Epoch 25, CIFAR-10 Batch 4:  loss 2.31796, acc 0.2
# Epoch 25, CIFAR-10 Batch 5:  loss 2.48665, acc 0.375
# Epoch 26, CIFAR-10 Batch 1:  loss 2.18597, acc 0.3
# Epoch 26, CIFAR-10 Batch 2:  loss 2.49956, acc 0.35
# Epoch 26, CIFAR-10 Batch 3:  loss 1.93905, acc 0.275
# Epoch 26, CIFAR-10 Batch 4:  loss 2.22134, acc 0.2
# Epoch 26, CIFAR-10 Batch 5:  loss 2.41379, acc 0.375
# Epoch 27, CIFAR-10 Batch 1:  loss 2.14579, acc 0.3
# Epoch 27, CIFAR-10 Batch 2:  loss 2.40696, acc 0.35
# Epoch 27, CIFAR-10 Batch 3:  loss 1.86654, acc 0.275
# Epoch 27, CIFAR-10 Batch 4:  loss 2.14239, acc 0.2
# Epoch 27, CIFAR-10 Batch 5:  loss 2.35021, acc 0.375
# Epoch 28, CIFAR-10 Batch 1:  loss 2.11351, acc 0.325
# Epoch 28, CIFAR-10 Batch 2:  loss 2.3257, acc 0.35
# Epoch 28, CIFAR-10 Batch 3:  loss 1.80761, acc 0.275
# Epoch 28, CIFAR-10 Batch 4:  loss 2.08402, acc 0.2
# Epoch 28, CIFAR-10 Batch 5:  loss 2.29765, acc 0.375
# Epoch 29, CIFAR-10 Batch 1:  loss 2.08219, acc 0.325
# Epoch 29, CIFAR-10 Batch 2:  loss 2.25492, acc 0.375
# Epoch 29, CIFAR-10 Batch 3:  loss 1.75974, acc 0.3
# Epoch 29, CIFAR-10 Batch 4:  loss 2.03597, acc 0.225
# Epoch 29, CIFAR-10 Batch 5:  loss 2.25841, acc 0.375
# Epoch 30, CIFAR-10 Batch 1:  loss 2.05751, acc 0.3
# Epoch 30, CIFAR-10 Batch 2:  loss 2.1938, acc 0.325
# Epoch 30, CIFAR-10 Batch 3:  loss 1.72242, acc 0.325
# Epoch 30, CIFAR-10 Batch 4:  loss 1.99303, acc 0.2
# Epoch 30, CIFAR-10 Batch 5:  loss 2.22342, acc 0.375
# Epoch 31, CIFAR-10 Batch 1:  loss 2.03841, acc 0.3
# Epoch 31, CIFAR-10 Batch 2:  loss 2.13783, acc 0.325
# Epoch 31, CIFAR-10 Batch 3:  loss 1.69156, acc 0.35
# Epoch 31, CIFAR-10 Batch 4:  loss 1.95942, acc 0.225
# Epoch 31, CIFAR-10 Batch 5:  loss 2.19443, acc 0.35
# Epoch 32, CIFAR-10 Batch 1:  loss 2.01779, acc 0.3
# Epoch 32, CIFAR-10 Batch 2:  loss 2.08664, acc 0.35
# Epoch 32, CIFAR-10 Batch 3:  loss 1.66689, acc 0.375
# Epoch 32, CIFAR-10 Batch 4:  loss 1.92939, acc 0.25
# Epoch 32, CIFAR-10 Batch 5:  loss 2.16723, acc 0.35
# Epoch 33, CIFAR-10 Batch 1:  loss 2.0035, acc 0.3
# Epoch 33, CIFAR-10 Batch 2:  loss 2.04503, acc 0.375
# Epoch 33, CIFAR-10 Batch 3:  loss 1.64232, acc 0.375
# Epoch 33, CIFAR-10 Batch 4:  loss 1.90183, acc 0.225
# Epoch 33, CIFAR-10 Batch 5:  loss 2.14126, acc 0.375
# Epoch 34, CIFAR-10 Batch 1:  loss 1.985, acc 0.325
# Epoch 34, CIFAR-10 Batch 2:  loss 2.00747, acc 0.375
# Epoch 34, CIFAR-10 Batch 3:  loss 1.62359, acc 0.35
# Epoch 34, CIFAR-10 Batch 4:  loss 1.87672, acc 0.25
# Epoch 34, CIFAR-10 Batch 5:  loss 2.12212, acc 0.35
# Epoch 35, CIFAR-10 Batch 1:  loss 1.97074, acc 0.325
# Epoch 35, CIFAR-10 Batch 2:  loss 1.97783, acc 0.35
# Epoch 35, CIFAR-10 Batch 3:  loss 1.60318, acc 0.375
# Epoch 35, CIFAR-10 Batch 4:  loss 1.85543, acc 0.275
# Epoch 35, CIFAR-10 Batch 5:  loss 2.10193, acc 0.35
# Epoch 36, CIFAR-10 Batch 1:  loss 1.96045, acc 0.3
# Epoch 36, CIFAR-10 Batch 2:  loss 1.94814, acc 0.35
# Epoch 36, CIFAR-10 Batch 3:  loss 1.58376, acc 0.35
# Epoch 36, CIFAR-10 Batch 4:  loss 1.83645, acc 0.275
# Epoch 36, CIFAR-10 Batch 5:  loss 2.08028, acc 0.375
# Epoch 37, CIFAR-10 Batch 1:  loss 1.94473, acc 0.3
# Epoch 37, CIFAR-10 Batch 2:  loss 1.91855, acc 0.35
# Epoch 37, CIFAR-10 Batch 3:  loss 1.57011, acc 0.325
# Epoch 37, CIFAR-10 Batch 4:  loss 1.82291, acc 0.25
# Epoch 37, CIFAR-10 Batch 5:  loss 2.06106, acc 0.375
# Epoch 38, CIFAR-10 Batch 1:  loss 1.92693, acc 0.3
# Epoch 38, CIFAR-10 Batch 2:  loss 1.89154, acc 0.35
# Epoch 38, CIFAR-10 Batch 3:  loss 1.55959, acc 0.325
# Epoch 38, CIFAR-10 Batch 4:  loss 1.8085, acc 0.25
# Epoch 38, CIFAR-10 Batch 5:  loss 2.04335, acc 0.375
# Epoch 39, CIFAR-10 Batch 1:  loss 1.907, acc 0.275
# Epoch 39, CIFAR-10 Batch 2:  loss 1.86617, acc 0.35
# Epoch 39, CIFAR-10 Batch 3:  loss 1.5456, acc 0.325
# Epoch 39, CIFAR-10 Batch 4:  loss 1.7949, acc 0.25
# Epoch 39, CIFAR-10 Batch 5:  loss 2.02453, acc 0.375
# Epoch 40, CIFAR-10 Batch 1:  loss 1.88792, acc 0.275
# Epoch 40, CIFAR-10 Batch 2:  loss 1.84559, acc 0.35
# Epoch 40, CIFAR-10 Batch 3:  loss 1.53272, acc 0.325
# Epoch 40, CIFAR-10 Batch 4:  loss 1.7818, acc 0.275
# Epoch 40, CIFAR-10 Batch 5:  loss 2.00495, acc 0.375
# Epoch 41, CIFAR-10 Batch 1:  loss 1.87122, acc 0.3
# Epoch 41, CIFAR-10 Batch 2:  loss 1.82952, acc 0.375
# Epoch 41, CIFAR-10 Batch 3:  loss 1.52042, acc 0.325
# Epoch 41, CIFAR-10 Batch 4:  loss 1.7689, acc 0.3
# Epoch 41, CIFAR-10 Batch 5:  loss 1.98539, acc 0.35
# Epoch 42, CIFAR-10 Batch 1:  loss 1.85645, acc 0.3
# Epoch 42, CIFAR-10 Batch 2:  loss 1.81324, acc 0.375
# Epoch 42, CIFAR-10 Batch 3:  loss 1.50875, acc 0.325
# Epoch 42, CIFAR-10 Batch 4:  loss 1.75455, acc 0.3
# Epoch 42, CIFAR-10 Batch 5:  loss 1.96611, acc 0.35
# Epoch 43, CIFAR-10 Batch 1:  loss 1.84161, acc 0.3
# Epoch 43, CIFAR-10 Batch 2:  loss 1.79749, acc 0.375
# Epoch 43, CIFAR-10 Batch 3:  loss 1.49859, acc 0.325
# Epoch 43, CIFAR-10 Batch 4:  loss 1.7425, acc 0.325
# Epoch 43, CIFAR-10 Batch 5:  loss 1.94737, acc 0.35
# Epoch 44, CIFAR-10 Batch 1:  loss 1.8267, acc 0.3
# Epoch 44, CIFAR-10 Batch 2:  loss 1.78298, acc 0.375
# Epoch 44, CIFAR-10 Batch 3:  loss 1.48725, acc 0.375
# Epoch 44, CIFAR-10 Batch 4:  loss 1.72936, acc 0.325
# Epoch 44, CIFAR-10 Batch 5:  loss 1.92623, acc 0.325
# Epoch 45, CIFAR-10 Batch 1:  loss 1.81216, acc 0.3
# Epoch 45, CIFAR-10 Batch 2:  loss 1.76905, acc 0.375
# Epoch 45, CIFAR-10 Batch 3:  loss 1.47639, acc 0.425
# Epoch 45, CIFAR-10 Batch 4:  loss 1.7185, acc 0.35
# Epoch 45, CIFAR-10 Batch 5:  loss 1.90718, acc 0.35
# Epoch 46, CIFAR-10 Batch 1:  loss 1.79821, acc 0.3
# Epoch 46, CIFAR-10 Batch 2:  loss 1.75563, acc 0.4
# Epoch 46, CIFAR-10 Batch 3:  loss 1.46662, acc 0.425
# Epoch 46, CIFAR-10 Batch 4:  loss 1.70892, acc 0.35
# Epoch 46, CIFAR-10 Batch 5:  loss 1.88903, acc 0.35
# Epoch 47, CIFAR-10 Batch 1:  loss 1.78422, acc 0.3
# Epoch 47, CIFAR-10 Batch 2:  loss 1.74304, acc 0.4
# Epoch 47, CIFAR-10 Batch 3:  loss 1.45773, acc 0.425
# Epoch 47, CIFAR-10 Batch 4:  loss 1.70105, acc 0.375
# Epoch 47, CIFAR-10 Batch 5:  loss 1.87094, acc 0.35
# Epoch 48, CIFAR-10 Batch 1:  loss 1.76852, acc 0.3
# Epoch 48, CIFAR-10 Batch 2:  loss 1.72996, acc 0.425
# Epoch 48, CIFAR-10 Batch 3:  loss 1.44794, acc 0.425
# Epoch 48, CIFAR-10 Batch 4:  loss 1.6937, acc 0.375
# Epoch 48, CIFAR-10 Batch 5:  loss 1.85395, acc 0.35
# Epoch 49, CIFAR-10 Batch 1:  loss 1.75729, acc 0.3
# Epoch 49, CIFAR-10 Batch 2:  loss 1.71645, acc 0.425
# Epoch 49, CIFAR-10 Batch 3:  loss 1.43755, acc 0.425
# Epoch 49, CIFAR-10 Batch 4:  loss 1.68515, acc 0.425
# Epoch 49, CIFAR-10 Batch 5:  loss 1.83926, acc 0.375
# Epoch 50, CIFAR-10 Batch 1:  loss 1.74544, acc 0.3
# Epoch 50, CIFAR-10 Batch 2:  loss 1.70046, acc 0.425
# Epoch 50, CIFAR-10 Batch 3:  loss 1.4266, acc 0.425
# Epoch 50, CIFAR-10 Batch 4:  loss 1.67664, acc 0.45
# Epoch 50, CIFAR-10 Batch 5:  loss 1.8231, acc 0.375
# Epoch 51, CIFAR-10 Batch 1:  loss 1.73479, acc 0.3
# Epoch 51, CIFAR-10 Batch 2:  loss 1.68317, acc 0.425
# Epoch 51, CIFAR-10 Batch 3:  loss 1.41607, acc 0.45
# Epoch 51, CIFAR-10 Batch 4:  loss 1.6692, acc 0.45
# Epoch 51, CIFAR-10 Batch 5:  loss 1.80602, acc 0.375
# Epoch 52, CIFAR-10 Batch 1:  loss 1.7234, acc 0.325
# Epoch 52, CIFAR-10 Batch 2:  loss 1.66753, acc 0.425
# Epoch 52, CIFAR-10 Batch 3:  loss 1.4053, acc 0.45
# Epoch 52, CIFAR-10 Batch 4:  loss 1.65992, acc 0.475
# Epoch 52, CIFAR-10 Batch 5:  loss 1.79157, acc 0.375
# Epoch 53, CIFAR-10 Batch 1:  loss 1.71332, acc 0.375
# Epoch 53, CIFAR-10 Batch 2:  loss 1.65224, acc 0.4
# Epoch 53, CIFAR-10 Batch 3:  loss 1.39278, acc 0.475
# Epoch 53, CIFAR-10 Batch 4:  loss 1.65049, acc 0.475
# Epoch 53, CIFAR-10 Batch 5:  loss 1.77669, acc 0.375
# Epoch 54, CIFAR-10 Batch 1:  loss 1.70631, acc 0.375
# Epoch 54, CIFAR-10 Batch 2:  loss 1.63752, acc 0.425
# Epoch 54, CIFAR-10 Batch 3:  loss 1.38265, acc 0.45
# Epoch 54, CIFAR-10 Batch 4:  loss 1.63727, acc 0.475
# Epoch 54, CIFAR-10 Batch 5:  loss 1.75864, acc 0.35
# Epoch 55, CIFAR-10 Batch 1:  loss 1.69725, acc 0.375
# Epoch 55, CIFAR-10 Batch 2:  loss 1.62567, acc 0.425
# Epoch 55, CIFAR-10 Batch 3:  loss 1.37255, acc 0.45
# Epoch 55, CIFAR-10 Batch 4:  loss 1.62327, acc 0.475
# Epoch 55, CIFAR-10 Batch 5:  loss 1.74555, acc 0.375
# Epoch 56, CIFAR-10 Batch 1:  loss 1.69187, acc 0.375
# Epoch 56, CIFAR-10 Batch 2:  loss 1.61452, acc 0.45
# Epoch 56, CIFAR-10 Batch 3:  loss 1.36199, acc 0.45
# Epoch 56, CIFAR-10 Batch 4:  loss 1.61241, acc 0.5
# Epoch 56, CIFAR-10 Batch 5:  loss 1.73267, acc 0.375
# Epoch 57, CIFAR-10 Batch 1:  loss 1.68688, acc 0.375
# Epoch 57, CIFAR-10 Batch 2:  loss 1.60356, acc 0.45
# Epoch 57, CIFAR-10 Batch 3:  loss 1.35098, acc 0.45
# Epoch 57, CIFAR-10 Batch 4:  loss 1.60071, acc 0.5
# Epoch 57, CIFAR-10 Batch 5:  loss 1.72084, acc 0.4
# Epoch 58, CIFAR-10 Batch 1:  loss 1.68362, acc 0.375
# Epoch 58, CIFAR-10 Batch 2:  loss 1.5924, acc 0.45
# Epoch 58, CIFAR-10 Batch 3:  loss 1.34151, acc 0.45
# Epoch 58, CIFAR-10 Batch 4:  loss 1.59114, acc 0.5
# Epoch 58, CIFAR-10 Batch 5:  loss 1.70955, acc 0.425
# Epoch 59, CIFAR-10 Batch 1:  loss 1.67916, acc 0.35
# Epoch 59, CIFAR-10 Batch 2:  loss 1.58121, acc 0.45
# Epoch 59, CIFAR-10 Batch 3:  loss 1.3308, acc 0.45
# Epoch 59, CIFAR-10 Batch 4:  loss 1.58062, acc 0.5
# Epoch 59, CIFAR-10 Batch 5:  loss 1.69938, acc 0.425
# Epoch 60, CIFAR-10 Batch 1:  loss 1.67181, acc 0.325
# Epoch 60, CIFAR-10 Batch 2:  loss 1.57036, acc 0.425
# Epoch 60, CIFAR-10 Batch 3:  loss 1.3182, acc 0.425
# Epoch 60, CIFAR-10 Batch 4:  loss 1.57204, acc 0.5
# Epoch 60, CIFAR-10 Batch 5:  loss 1.68762, acc 0.4
# Epoch 61, CIFAR-10 Batch 1:  loss 1.66649, acc 0.325
# Epoch 61, CIFAR-10 Batch 2:  loss 1.55989, acc 0.425
# Epoch 61, CIFAR-10 Batch 3:  loss 1.30627, acc 0.425
# Epoch 61, CIFAR-10 Batch 4:  loss 1.56521, acc 0.5
# Epoch 61, CIFAR-10 Batch 5:  loss 1.67766, acc 0.425
# Epoch 62, CIFAR-10 Batch 1:  loss 1.65894, acc 0.35
# Epoch 62, CIFAR-10 Batch 2:  loss 1.54787, acc 0.425
# Epoch 62, CIFAR-10 Batch 3:  loss 1.29415, acc 0.475
# Epoch 62, CIFAR-10 Batch 4:  loss 1.55673, acc 0.5
# Epoch 62, CIFAR-10 Batch 5:  loss 1.66683, acc 0.425
# Epoch 63, CIFAR-10 Batch 1:  loss 1.65197, acc 0.35
# Epoch 63, CIFAR-10 Batch 2:  loss 1.53617, acc 0.45
# Epoch 63, CIFAR-10 Batch 3:  loss 1.28382, acc 0.475
# Epoch 63, CIFAR-10 Batch 4:  loss 1.54994, acc 0.525
# Epoch 63, CIFAR-10 Batch 5:  loss 1.65711, acc 0.425
# Epoch 64, CIFAR-10 Batch 1:  loss 1.64502, acc 0.325
# Epoch 64, CIFAR-10 Batch 2:  loss 1.52429, acc 0.45
# Epoch 64, CIFAR-10 Batch 3:  loss 1.27374, acc 0.475
# Epoch 64, CIFAR-10 Batch 4:  loss 1.54319, acc 0.525
# Epoch 64, CIFAR-10 Batch 5:  loss 1.64955, acc 0.425
# Epoch 65, CIFAR-10 Batch 1:  loss 1.63859, acc 0.325
# Epoch 65, CIFAR-10 Batch 2:  loss 1.51241, acc 0.45
# Epoch 65, CIFAR-10 Batch 3:  loss 1.26441, acc 0.475
# Epoch 65, CIFAR-10 Batch 4:  loss 1.53589, acc 0.525
# Epoch 65, CIFAR-10 Batch 5:  loss 1.63897, acc 0.45
# Epoch 66, CIFAR-10 Batch 1:  loss 1.63229, acc 0.325
# Epoch 66, CIFAR-10 Batch 2:  loss 1.50084, acc 0.45
# Epoch 66, CIFAR-10 Batch 3:  loss 1.2561, acc 0.5
# Epoch 66, CIFAR-10 Batch 4:  loss 1.53002, acc 0.525
# Epoch 66, CIFAR-10 Batch 5:  loss 1.62879, acc 0.45
# Epoch 67, CIFAR-10 Batch 1:  loss 1.62622, acc 0.325
# Epoch 67, CIFAR-10 Batch 2:  loss 1.48998, acc 0.45
# Epoch 67, CIFAR-10 Batch 3:  loss 1.2476, acc 0.5
# Epoch 67, CIFAR-10 Batch 4:  loss 1.52252, acc 0.525
# Epoch 67, CIFAR-10 Batch 5:  loss 1.61927, acc 0.45
# Epoch 68, CIFAR-10 Batch 1:  loss 1.61959, acc 0.325
# Epoch 68, CIFAR-10 Batch 2:  loss 1.479, acc 0.45
# Epoch 68, CIFAR-10 Batch 3:  loss 1.2392, acc 0.55
# Epoch 68, CIFAR-10 Batch 4:  loss 1.51501, acc 0.525
# Epoch 68, CIFAR-10 Batch 5:  loss 1.60987, acc 0.45
# Epoch 69, CIFAR-10 Batch 1:  loss 1.61338, acc 0.35
# Epoch 69, CIFAR-10 Batch 2:  loss 1.46934, acc 0.45
# Epoch 69, CIFAR-10 Batch 3:  loss 1.23103, acc 0.55
# Epoch 69, CIFAR-10 Batch 4:  loss 1.50759, acc 0.525
# Epoch 69, CIFAR-10 Batch 5:  loss 1.60142, acc 0.425
# Epoch 70, CIFAR-10 Batch 1:  loss 1.60637, acc 0.35
# Epoch 70, CIFAR-10 Batch 2:  loss 1.45949, acc 0.45
# Epoch 70, CIFAR-10 Batch 3:  loss 1.22303, acc 0.55
# Epoch 70, CIFAR-10 Batch 4:  loss 1.50038, acc 0.525
# Epoch 70, CIFAR-10 Batch 5:  loss 1.59432, acc 0.425
# Epoch 71, CIFAR-10 Batch 1:  loss 1.5993, acc 0.35
# Epoch 71, CIFAR-10 Batch 2:  loss 1.44957, acc 0.45
# Epoch 71, CIFAR-10 Batch 3:  loss 1.21443, acc 0.55
# Epoch 71, CIFAR-10 Batch 4:  loss 1.4925, acc 0.55
# Epoch 71, CIFAR-10 Batch 5:  loss 1.58762, acc 0.425
# Epoch 72, CIFAR-10 Batch 1:  loss 1.59233, acc 0.375
# Epoch 72, CIFAR-10 Batch 2:  loss 1.43982, acc 0.45
# Epoch 72, CIFAR-10 Batch 3:  loss 1.20616, acc 0.55
# Epoch 72, CIFAR-10 Batch 4:  loss 1.48425, acc 0.55
# Epoch 72, CIFAR-10 Batch 5:  loss 1.57987, acc 0.425
# Epoch 73, CIFAR-10 Batch 1:  loss 1.58544, acc 0.375
# Epoch 73, CIFAR-10 Batch 2:  loss 1.43009, acc 0.45
# Epoch 73, CIFAR-10 Batch 3:  loss 1.19865, acc 0.55
# Epoch 73, CIFAR-10 Batch 4:  loss 1.47623, acc 0.55
# Epoch 73, CIFAR-10 Batch 5:  loss 1.57152, acc 0.425
# Epoch 74, CIFAR-10 Batch 1:  loss 1.57877, acc 0.4
# Epoch 74, CIFAR-10 Batch 2:  loss 1.42017, acc 0.45
# Epoch 74, CIFAR-10 Batch 3:  loss 1.19148, acc 0.575
# Epoch 74, CIFAR-10 Batch 4:  loss 1.46863, acc 0.55
# Epoch 74, CIFAR-10 Batch 5:  loss 1.56467, acc 0.425
# Epoch 75, CIFAR-10 Batch 1:  loss 1.57248, acc 0.425
# Epoch 75, CIFAR-10 Batch 2:  loss 1.40964, acc 0.45
# Epoch 75, CIFAR-10 Batch 3:  loss 1.18419, acc 0.575
# Epoch 75, CIFAR-10 Batch 4:  loss 1.46098, acc 0.55
# Epoch 75, CIFAR-10 Batch 5:  loss 1.55755, acc 0.45
# Epoch 76, CIFAR-10 Batch 1:  loss 1.56715, acc 0.45
# Epoch 76, CIFAR-10 Batch 2:  loss 1.39878, acc 0.45
# Epoch 76, CIFAR-10 Batch 3:  loss 1.17736, acc 0.575
# Epoch 76, CIFAR-10 Batch 4:  loss 1.45252, acc 0.55
# Epoch 76, CIFAR-10 Batch 5:  loss 1.55048, acc 0.45
# Epoch 77, CIFAR-10 Batch 1:  loss 1.56193, acc 0.45
# Epoch 77, CIFAR-10 Batch 2:  loss 1.38971, acc 0.45
# Epoch 77, CIFAR-10 Batch 3:  loss 1.17018, acc 0.6
# Epoch 77, CIFAR-10 Batch 4:  loss 1.44431, acc 0.55
# Epoch 77, CIFAR-10 Batch 5:  loss 1.54393, acc 0.45
# Epoch 78, CIFAR-10 Batch 1:  loss 1.55652, acc 0.45
# Epoch 78, CIFAR-10 Batch 2:  loss 1.37993, acc 0.475
# Epoch 78, CIFAR-10 Batch 3:  loss 1.16418, acc 0.6
# Epoch 78, CIFAR-10 Batch 4:  loss 1.43615, acc 0.55
# Epoch 78, CIFAR-10 Batch 5:  loss 1.53828, acc 0.45
# Epoch 79, CIFAR-10 Batch 1:  loss 1.55163, acc 0.45
# Epoch 79, CIFAR-10 Batch 2:  loss 1.36956, acc 0.475
# Epoch 79, CIFAR-10 Batch 3:  loss 1.15819, acc 0.6
# Epoch 79, CIFAR-10 Batch 4:  loss 1.42838, acc 0.55
# Epoch 79, CIFAR-10 Batch 5:  loss 1.53259, acc 0.45
# Epoch 80, CIFAR-10 Batch 1:  loss 1.54659, acc 0.45
# Epoch 80, CIFAR-10 Batch 2:  loss 1.35947, acc 0.5
# Epoch 80, CIFAR-10 Batch 3:  loss 1.15315, acc 0.575
# Epoch 80, CIFAR-10 Batch 4:  loss 1.42117, acc 0.55
# Epoch 80, CIFAR-10 Batch 5:  loss 1.52728, acc 0.45
# Epoch 81, CIFAR-10 Batch 1:  loss 1.54124, acc 0.475
# Epoch 81, CIFAR-10 Batch 2:  loss 1.34999, acc 0.5
# Epoch 81, CIFAR-10 Batch 3:  loss 1.14846, acc 0.575
# Epoch 81, CIFAR-10 Batch 4:  loss 1.41414, acc 0.55
# Epoch 81, CIFAR-10 Batch 5:  loss 1.52152, acc 0.475
# Epoch 82, CIFAR-10 Batch 1:  loss 1.53592, acc 0.475
# Epoch 82, CIFAR-10 Batch 2:  loss 1.33944, acc 0.5
# Epoch 82, CIFAR-10 Batch 3:  loss 1.14321, acc 0.575
# Epoch 82, CIFAR-10 Batch 4:  loss 1.40633, acc 0.575
# Epoch 82, CIFAR-10 Batch 5:  loss 1.51517, acc 0.475
# Epoch 83, CIFAR-10 Batch 1:  loss 1.5293, acc 0.475
# Epoch 83, CIFAR-10 Batch 2:  loss 1.32939, acc 0.5
# Epoch 83, CIFAR-10 Batch 3:  loss 1.13823, acc 0.575
# Epoch 83, CIFAR-10 Batch 4:  loss 1.39874, acc 0.575
# Epoch 83, CIFAR-10 Batch 5:  loss 1.50963, acc 0.475
# Epoch 84, CIFAR-10 Batch 1:  loss 1.52403, acc 0.475
# Epoch 84, CIFAR-10 Batch 2:  loss 1.32071, acc 0.5
# Epoch 84, CIFAR-10 Batch 3:  loss 1.13401, acc 0.575
# Epoch 84, CIFAR-10 Batch 4:  loss 1.39169, acc 0.575
# Epoch 84, CIFAR-10 Batch 5:  loss 1.50507, acc 0.475
# Epoch 85, CIFAR-10 Batch 1:  loss 1.51977, acc 0.475
# Epoch 85, CIFAR-10 Batch 2:  loss 1.31182, acc 0.5
# Epoch 85, CIFAR-10 Batch 3:  loss 1.1295, acc 0.575
# Epoch 85, CIFAR-10 Batch 4:  loss 1.38455, acc 0.6
# Epoch 85, CIFAR-10 Batch 5:  loss 1.50132, acc 0.475
# Epoch 86, CIFAR-10 Batch 1:  loss 1.51516, acc 0.5
# Epoch 86, CIFAR-10 Batch 2:  loss 1.30359, acc 0.5
# Epoch 86, CIFAR-10 Batch 3:  loss 1.12537, acc 0.575
# Epoch 86, CIFAR-10 Batch 4:  loss 1.378, acc 0.6
# Epoch 86, CIFAR-10 Batch 5:  loss 1.4982, acc 0.475
# Epoch 87, CIFAR-10 Batch 1:  loss 1.51043, acc 0.5
# Epoch 87, CIFAR-10 Batch 2:  loss 1.2962, acc 0.5
# Epoch 87, CIFAR-10 Batch 3:  loss 1.12133, acc 0.575
# Epoch 87, CIFAR-10 Batch 4:  loss 1.37144, acc 0.6
# Epoch 87, CIFAR-10 Batch 5:  loss 1.49573, acc 0.475
# Epoch 88, CIFAR-10 Batch 1:  loss 1.50606, acc 0.5
# Epoch 88, CIFAR-10 Batch 2:  loss 1.2888, acc 0.5
# Epoch 88, CIFAR-10 Batch 3:  loss 1.11627, acc 0.575
# Epoch 88, CIFAR-10 Batch 4:  loss 1.36569, acc 0.6
# Epoch 88, CIFAR-10 Batch 5:  loss 1.49246, acc 0.5
# Epoch 89, CIFAR-10 Batch 1:  loss 1.50276, acc 0.5
# Epoch 89, CIFAR-10 Batch 2:  loss 1.28178, acc 0.5
# Epoch 89, CIFAR-10 Batch 3:  loss 1.1117, acc 0.6
# Epoch 89, CIFAR-10 Batch 4:  loss 1.35931, acc 0.6
# Epoch 89, CIFAR-10 Batch 5:  loss 1.48909, acc 0.5
# Epoch 90, CIFAR-10 Batch 1:  loss 1.49995, acc 0.5
# Epoch 90, CIFAR-10 Batch 2:  loss 1.27471, acc 0.5
# Epoch 90, CIFAR-10 Batch 3:  loss 1.10751, acc 0.6
# Epoch 90, CIFAR-10 Batch 4:  loss 1.35352, acc 0.6
# Epoch 90, CIFAR-10 Batch 5:  loss 1.48653, acc 0.5
# Epoch 91, CIFAR-10 Batch 1:  loss 1.49653, acc 0.5
# Epoch 91, CIFAR-10 Batch 2:  loss 1.2679, acc 0.525
# Epoch 91, CIFAR-10 Batch 3:  loss 1.10354, acc 0.625
# Epoch 91, CIFAR-10 Batch 4:  loss 1.34842, acc 0.6
# Epoch 91, CIFAR-10 Batch 5:  loss 1.48416, acc 0.5
# Epoch 92, CIFAR-10 Batch 1:  loss 1.49325, acc 0.5
# Epoch 92, CIFAR-10 Batch 2:  loss 1.26114, acc 0.525
# Epoch 92, CIFAR-10 Batch 3:  loss 1.09995, acc 0.625
# Epoch 92, CIFAR-10 Batch 4:  loss 1.34376, acc 0.6
# Epoch 92, CIFAR-10 Batch 5:  loss 1.48166, acc 0.5
# Epoch 93, CIFAR-10 Batch 1:  loss 1.49032, acc 0.5
# Epoch 93, CIFAR-10 Batch 2:  loss 1.25465, acc 0.525
# Epoch 93, CIFAR-10 Batch 3:  loss 1.09615, acc 0.625
# Epoch 93, CIFAR-10 Batch 4:  loss 1.33872, acc 0.6
# Epoch 93, CIFAR-10 Batch 5:  loss 1.4792, acc 0.5
# Epoch 94, CIFAR-10 Batch 1:  loss 1.48892, acc 0.5
# Epoch 94, CIFAR-10 Batch 2:  loss 1.2483, acc 0.525
# Epoch 94, CIFAR-10 Batch 3:  loss 1.09235, acc 0.6
# Epoch 94, CIFAR-10 Batch 4:  loss 1.33403, acc 0.6
# Epoch 94, CIFAR-10 Batch 5:  loss 1.47679, acc 0.5
# Epoch 95, CIFAR-10 Batch 1:  loss 1.48727, acc 0.5
# Epoch 95, CIFAR-10 Batch 2:  loss 1.24248, acc 0.525
# Epoch 95, CIFAR-10 Batch 3:  loss 1.08877, acc 0.625
# Epoch 95, CIFAR-10 Batch 4:  loss 1.32975, acc 0.6
# Epoch 95, CIFAR-10 Batch 5:  loss 1.47496, acc 0.5
# Epoch 96, CIFAR-10 Batch 1:  loss 1.4854, acc 0.5
# Epoch 96, CIFAR-10 Batch 2:  loss 1.23728, acc 0.525
# Epoch 96, CIFAR-10 Batch 3:  loss 1.08566, acc 0.625
# Epoch 96, CIFAR-10 Batch 4:  loss 1.32582, acc 0.6
# Epoch 96, CIFAR-10 Batch 5:  loss 1.47317, acc 0.525
# Epoch 97, CIFAR-10 Batch 1:  loss 1.48359, acc 0.5
# Epoch 97, CIFAR-10 Batch 2:  loss 1.23168, acc 0.525
# Epoch 97, CIFAR-10 Batch 3:  loss 1.08252, acc 0.625
# Epoch 97, CIFAR-10 Batch 4:  loss 1.32213, acc 0.6
# Epoch 97, CIFAR-10 Batch 5:  loss 1.47098, acc 0.525
# Epoch 98, CIFAR-10 Batch 1:  loss 1.48203, acc 0.5
# Epoch 98, CIFAR-10 Batch 2:  loss 1.22654, acc 0.525
# Epoch 98, CIFAR-10 Batch 3:  loss 1.0791, acc 0.625
# Epoch 98, CIFAR-10 Batch 4:  loss 1.31856, acc 0.6
# Epoch 98, CIFAR-10 Batch 5:  loss 1.46935, acc 0.525
# Epoch 99, CIFAR-10 Batch 1:  loss 1.48, acc 0.5
# Epoch 99, CIFAR-10 Batch 2:  loss 1.22152, acc 0.525
# Epoch 99, CIFAR-10 Batch 3:  loss 1.07561, acc 0.625
# Epoch 99, CIFAR-10 Batch 4:  loss 1.31481, acc 0.6
# Epoch 99, CIFAR-10 Batch 5:  loss 1.46753, acc 0.525
# Epoch 100, CIFAR-10 Batch 1:  loss 1.47785, acc 0.475
# Epoch 100, CIFAR-10 Batch 2:  loss 1.21651, acc 0.525
# Epoch 100, CIFAR-10 Batch 3:  loss 1.07217, acc 0.625
# Epoch 100, CIFAR-10 Batch 4:  loss 1.31095, acc 0.625
# Epoch 100, CIFAR-10 Batch 5:  loss 1.4656, acc 0.525

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.46435546875

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
